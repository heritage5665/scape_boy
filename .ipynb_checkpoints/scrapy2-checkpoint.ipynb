# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# %%
page = requests.get(url)
soup = bs(page.text, 'html.parser')

# %%
data = []
data_iterator = iter(soup.find_all('td'))

# %%
while True:
    try:
        _data={
            "country": next(data_iterator).text,
            "confirmed":int(next(data_iterator).text.replace(',','')),
            "death": int(next(data_iterator).text.replace(',','')),
            "continent": next(data_iterator).text }
        data.append(_data)
 
   
    except StopIteration:
        break

# %%
covid_df = pd.DataFrame (data, columns = ['country','confirmed','death',"continent"])

# %%
covid_df.to_csv('covid_cases.csv')
print(covid_df.describe())
print(covid_df[['confirmed','death','continent']].groupby('continent').describe())
covid_df[['confirmed','death','continent']].groupby('continent').plot(kind='bar')
covid_df.plot(kind = 'bar',x='country', y = "death")
# Out:
#           confirmed          death
# count  2.200000e+02     220.000000
# mean   5.701097e+05   12530.281818
# std    2.441283e+06   48659.341147
# min    1.000000e+00       0.000000
# 25%    4.093250e+03      56.000000
# 50%    3.670950e+04     519.500000
# 75%    2.458672e+05    4523.750000
# max    3.070429e+07  558422.000000
#                   confirmed                                              \
#                       count          mean           std   min       25%
# continent
#                         1.0  9.000000e+00           NaN   9.0      9.00
# Africa                 57.0  7.313609e+04  2.140038e+05  10.0   5303.00
# Asia                   49.0  5.585729e+05  1.726069e+06  48.0  17896.00
# Australia/Oceania      12.0  4.580333e+03  9.398052e+03   1.0      3.75
# Europe                 48.0  7.949043e+05  1.244694e+06  27.0  70113.75
# North America          39.0  9.057096e+05  4.911986e+06  20.0    807.50
# South America          14.0  1.453733e+06  3.210280e+06  54.0  34644.50
#
#                                                     death                \
#                         50%         75%         max count          mean
# continent
#                         9.0        9.00         9.0   1.0      2.000000
# Africa              17690.0    40719.00   1540009.0  57.0   1948.491228
# Asia               142292.0   446594.00  11787013.0  49.0   8565.326531
# Australia/Oceania      91.5     2884.25     29228.0  12.0     93.333333
# Europe             230029.0   824784.00   4483471.0  48.0  18522.062500
# North America        6424.0    50218.00  30704292.0  39.0  20740.128205
# South America      233941.0  1356335.00  12227179.0  14.0  37632.214286
#
#
#                             std  min     25%     50%       75%       max
# continent
#                             NaN  2.0    2.00     2.0      2.00       2.0
# Africa              7148.991687  1.0  102.00   297.0    752.00   52372.0
# Asia               24834.528693  0.0   92.00  1492.0   5903.00  160726.0
# Australia/Oceania    260.041722  0.0    0.00     1.0     29.25     909.0
# Europe             31598.306397  0.0  710.00  4644.5  17341.75  126382.0
# North America      93970.117221  0.0    6.00    49.0    475.00  558422.0
# South America      79054.507915  0.0  375.75  7988.0  43592.50  301087.0
# <AxesSubplot:xlabel='country'>

# %%
url_today ='https://www.worldometers.info/coronavirus/#countries'
soup2 = bs(requests.get(url_today).text,'html.parser')

# %%
covid_response = soup2.find_all('tr',  attrs = {'style':''})
data_iterator2 = iter(covid_response[1:])
data_covid =[]
while True:
    try:
        _s = next(data_iterator2).text.split("\n")
        data_covid.append(_s)
    except StopIteration:
        break    
data_covid[2:]
# Out:
# [['',
#   '2',
#   'Brazil',
#   '12,227,179',
#   '',
#   '301,087 ',
#   '',
#   '10,689,646',
#   '',
#   '1,236,446',
#   '8,318',
#   '57,228',
#   '1,409',
#   '28,600,000',
#   '133,858',
#   '213,658,752 ',
#   'South America',
#   '177107',
#   ''],
#  ['',
#   '3',
#   'India',
#   '11,787,534',
#   '+521',
#   '160,726 ',
#   '',
#   '11,231,650',
#   '+2,059',
#   '395,158',
#   '8,944',
#   '8,481',
#   '116',
#   '237,503,882',
#   '170,883',
#   '1,389,864,267 ',
#   'Asia',
#   '1188,6476',
#   ''],
#  ['',
#   '4',
#   'Russia',
#   '4,492,692',
#   '+9,221',
#   '96,612 ',
#   '+393',
#   '4,109,281',
#   '+10,881',
#   '286,799',
#   '2,300',
#   '30,776',
#   '662',
#   '118,500,000',
#   '811,754',
#   '145,980,114 ',
#   'Europe',
#   '321,5111',
#   ''],
#  ['',
#   '5',
#   'France',
#   '4,378,446',
#   '',
#   '93,180 ',
#   '',
#   '283,507',
#   '',
#   '4,001,759',
#   '4,634',
#   '66,970',
#   '1,425',
#   '60,773,434',
#   '929,559',
#   '65,378,809 ',
#   'Europe',
#   '157021',
#   ''],
#  ['',
#   '6',
#   'UK',
#   '4,312,908',
#   '',
#   '126,382 ',
#   '',
#   '3,729,155',
#   '',
#   '457,371',
#   '711',
#   '63,290',
#   '1,855',
#   '118,204,895',
#   '1,734,591',
#   '68,145,669 ',
#   'Europe',
#   '165391',
#   ''],
#  ['',
#   '7',
#   'Italy',
#   '3,440,862',
#   '',
#   '106,339 ',
#   '',
#   '2,773,215',
#   '',
#   '561,308',
#   '3,588',
#   '56,971',
#   '1,761',
#   '47,759,055',
#   '790,753',
#   '60,396,918 ',
#   'Europe',
#   '185681',
#   ''],
#  ['',
#   '8',
#   'Spain',
#   '3,241,345',
#   '',
#   '74,064  ',
#   '',
#   '3,000,670',
#   '',
#   '166,611',
#   '1,855',
#   '69,307',
#   '1,584',
#   '41,884,958',
#   '895,590',
#   '46,767,990 ',
#   'Europe',
#   '146311',
#   ''],
#  ['',
#   '9',
#   'Turkey',
#   '3,091,282',
#   '',
#   '30,462 ',
#   '',
#   '2,881,643',
#   '',
#   '179,177',
#   '1,720',
#   '36,369',
#   '358',
#   '36,990,175',
#   '435,187',
#   '84,998,318 ',
#   'Asia',
#   '272,7902',
#   ''],
#  ['',
#   '10',
#   'Germany',
#   '2,709,872',
#   '',
#   '75,911 ',
#   '',
#   '2,456,200',
#   '+10,900',
#   '177,761',
#   '3,209',
#   '32,268',
#   '904',
#   '48,979,281',
#   '583,231',
#   '83,979,174 ',
#   'Europe',
#   '311,1062',
#   ''],
#  ['',
#   '11',
#   'Colombia',
#   '2,353,210',
#   '',
#   '62,394 ',
#   '',
#   '2,244,522',
#   '',
#   '46,294',
#   '1,982',
#   '45,892',
#   '1,217',
#   '12,386,993',
#   '241,571',
#   '51,276,879 ',
#   'South America',
#   '228224',
#   ''],
#  ['',
#   '12',
#   'Argentina',
#   '2,269,877',
#   '',
#   '54,946 ',
#   '',
#   '2,049,035',
#   '',
#   '165,896',
#   '3,574',
#   '49,890',
#   '1,208',
#   '8,477,597',
#   '186,332',
#   '45,497,251 ',
#   'South America',
#   '208285',
#   ''],
#  ['',
#   '13',
#   'Mexico',
#   '2,208,755',
#   '+5,714',
#   '199,627 ',
#   '+579',
#   '1,748,317',
#   '+4,055',
#   '260,811',
#   '4,798',
#   '17,001',
#   '1,537',
#   '5,957,631',
#   '45,857',
#   '129,916,892 ',
#   'North America',
#   '5965122',
#   ''],
#  ['',
#   '14',
#   'Poland',
#   '2,154,821',
#   '+34,151',
#   '50,860 ',
#   '+520',
#   '1,722,856',
#   '+15,010',
#   '381,105',
#   '2,620',
#   '56,981',
#   '1,345',
#   '11,503,034',
#   '304,181',
#   '37,816,353 ',
#   'Europe',
#   '187443',
#   ''],
#  ['',
#   '15',
#   'Iran',
#   '1,823,317',
#   '',
#   '62,045 ',
#   '',
#   '1,562,709',
#   '',
#   '198,563',
#   '3,874',
#   '21,508',
#   '732',
#   '12,349,804',
#   '145,681',
#   '84,773,193 ',
#   'Asia',
#   '461,3667',
#   ''],
#  ['',
#   '16',
#   'Ukraine',
#   '1,596,575',
#   '+16,669',
#   '31,135 ',
#   '+362',
#   '1,283,020',
#   '+6,748',
#   '282,420',
#   '177',
#   '36,668',
#   '715',
#   '7,836,049',
#   '179,967',
#   '43,541,616 ',
#   'Europe',
#   '271,3986',
#   ''],
#  ['',
#   '17',
#   'South Africa',
#   '1,540,009',
#   '',
#   '52,372 ',
#   '',
#   '1,466,595',
#   '',
#   '21,042',
#   '546',
#   '25,731',
#   '875',
#   '9,690,815',
#   '161,914',
#   '59,851,438 ',
#   'Africa',
#   '391,1436',
#   ''],
#  ['',
#   '18',
#   'Czechia',
#   '1,495,361',
#   '+8,763',
#   '25,450 ',
#   '+83',
#   '1,295,205',
#   '+297',
#   '174,706',
#   '1,874',
#   '139,448',
#   '2,373',
#   '11,490,915',
#   '1,071,567',
#   '10,723,467 ',
#   'Europe',
#   '74211',
#   ''],
#  ['',
#   '19',
#   'Peru',
#   '1,492,519',
#   '',
#   '50,656 ',
#   '',
#   '1,406,304',
#   '',
#   '35,559',
#   '2,253',
#   '44,814',
#   '1,521',
#   '8,881,594',
#   '266,674',
#   '33,305,026 ',
#   'South America',
#   '226574',
#   ''],
#  ['',
#   '20',
#   'Indonesia',
#   '1,482,559',
#   '+6,107',
#   '40,081 ',
#   '+98',
#   '1,317,199',
#   '+4,656',
#   '125,279',
#   '',
#   '5,379',
#   '145',
#   '12,270,150',
#   '44,518',
#   '275,624,849 ',
#   'Asia',
#   '1866,87722',
#   ''],
#  ['',
#   '21',
#   'Netherlands',
#   '1,220,945',
#   '',
#   '16,371 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '625',
#   '71,140',
#   '954',
#   '9,747,836',
#   '567,973',
#   '17,162,512 ',
#   'Europe',
#   '141,0482',
#   ''],
#  ['',
#   '22',
#   'Chile',
#   '947,783',
#   '',
#   '22,402 ',
#   '',
#   '888,826',
#   '',
#   '36,555',
#   '2,348',
#   '49,273',
#   '1,165',
#   '10,739,277',
#   '558,305',
#   '19,235,515 ',
#   'South America',
#   '208592',
#   ''],
#  ['',
#   '23',
#   'Canada',
#   '946,370',
#   '',
#   '22,759 ',
#   '',
#   '886,512',
#   '',
#   '37,099',
#   '586',
#   '24,916',
#   '599',
#   '26,858,481',
#   '707,123',
#   '37,982,749 ',
#   'North America',
#   '401,6691',
#   ''],
#  ['',
#   '24',
#   'Romania',
#   '919,794',
#   '+6,651',
#   '22,719 ',
#   '+140',
#   '825,208',
#   '+5,409',
#   '71,867',
#   '1,348',
#   '48,047',
#   '1,187',
#   '7,122,737',
#   '372,065',
#   '19,143,818 ',
#   'Europe',
#   '218433',
#   ''],
#  ['',
#   '25',
#   'Belgium',
#   '849,090',
#   '+6,315',
#   '22,786 ',
#   '+23',
#   '55,928',
#   '+236',
#   '770,376',
#   '601',
#   '73,031',
#   '1,960',
#   '10,693,594',
#   '919,771',
#   '11,626,363 ',
#   'Europe',
#   '145101',
#   ''],
#  ['',
#   '26',
#   'Israel',
#   '830,515',
#   '+487',
#   '6,157 ',
#   '+3',
#   '811,452',
#   '+444',
#   '12,906',
#   '482',
#   '90,297',
#   '669',
#   '13,314,415',
#   '1,447,598',
#   '9,197,590 ',
#   'Asia',
#   '111,4941',
#   ''],
#  ['',
#   '27',
#   'Portugal',
#   '818,787',
#   '',
#   '16,805 ',
#   '',
#   '769,838',
#   '',
#   '32,144',
#   '155',
#   '80,471',
#   '1,652',
#   '8,892,180',
#   '873,925',
#   '10,174,991 ',
#   'Europe',
#   '126051',
#   ''],
#  ['',
#   '28',
#   'Iraq',
#   '809,092',
#   '',
#   '14,095 ',
#   '',
#   '727,471',
#   '',
#   '67,526',
#   '476',
#   '19,794',
#   '345',
#   '7,750,389',
#   '189,614',
#   '40,874,600 ',
#   'Asia',
#   '512,9005',
#   ''],
#  ['',
#   '29',
#   'Sweden',
#   '765,984',
#   '',
#   '13,357 ',
#   '',
#   'N/A',
#   'N/A',
#   'N/A',
#   '281',
#   '75,503',
#   '1,317',
#   '6,627,544',
#   '653,275',
#   '10,145,100 ',
#   'Europe',
#   '137602',
#   ''],
#  ['',
#   '30',
#   'Philippines',
#   '693,048',
#   '+8,773',
#   '13,095 ',
#   '+56',
#   '580,062',
#   '+574',
#   '99,891',
#   '785',
#   '6,264',
#   '118',
#   '9,816,140',
#   '88,722',
#   '110,639,355 ',
#   'Asia',
#   '1608,44911',
#   ''],
#  ['',
#   '31',
#   'Pakistan',
#   '640,988',
#   '+3,946',
#   '14,028 ',
#   '+63',
#   '588,975',
#   '+2,747',
#   '37,985',
#   '2,587',
#   '2,862',
#   '63',
#   '9,934,373',
#   '44,351',
#   '223,995,659 ',
#   'Asia',
#   '34915,96823',
#   ''],
#  ['',
#   '32',
#   'Hungary',
#   '603,347',
#   '+9,637',
#   '19,224 ',
#   '+272',
#   '387,570',
#   '+5,763',
#   '196,553',
#   '1,467',
#   '62,572',
#   '1,994',
#   '4,403,317',
#   '456,660',
#   '9,642,435 ',
#   'Europe',
#   '165022',
#   ''],
#  ['',
#   '33',
#   'Switzerland',
#   '588,118',
#   '',
#   '10,276 ',
#   '',
#   '540,106',
#   '',
#   '37,736',
#   '158',
#   '67,595',
#   '1,181',
#   '5,765,946',
#   '662,702',
#   '8,700,667 ',
#   'Europe',
#   '158472',
#   ''],
#  ['',
#   '34',
#   'Bangladesh',
#   '580,808',
#   '',
#   '8,763 ',
#   '',
#   '527,609',
#   '',
#   '44,436',
#   '',
#   '3,501',
#   '53',
#   '4,487,686',
#   '27,054',
#   '165,881,688 ',
#   'Asia',
#   '28618,93037',
#   ''],
#  ['',
#   '35',
#   'Serbia',
#   '566,669',
#   '',
#   '5,039 ',
#   '',
#   '477,395',
#   '',
#   '84,235',
#   '243',
#   '65,047',
#   '578',
#   '3,313,232',
#   '380,322',
#   '8,711,652 ',
#   'Europe',
#   '151,7293',
#   ''],
#  ['',
#   '36',
#   'Jordan',
#   '562,857',
#   '',
#   '6,181 ',
#   '',
#   '456,188',
#   '',
#   '100,488',
#   '729',
#   '54,770',
#   '601',
#   '5,617,586',
#   '546,631',
#   '10,276,741 ',
#   'Asia',
#   '181,6632',
#   ''],
#  ['',
#   '37',
#   'Austria',
#   '526,393',
#   '+3,124',
#   '9,178 ',
#   '+27',
#   '483,460',
#   '+2,863',
#   '33,755',
#   '446',
#   '58,205',
#   '1,015',
#   '6,568,554',
#   '726,304',
#   '9,043,809 ',
#   'Europe',
#   '179851',
#   ''],
#  ['',
#   '38',
#   'Morocco',
#   '492,842',
#   '',
#   '8,786 ',
#   '',
#   '480,607',
#   '',
#   '3,449',
#   '270',
#   '13,238',
#   '236',
#   '5,892,612',
#   '158,284',
#   '37,228,212 ',
#   'Africa',
#   '764,2376',
#   ''],
#  ['',
#   '39',
#   'Japan',
#   '459,043',
#   '',
#   '8,908 ',
#   '',
#   '436,463',
#   '',
#   '13,672',
#   '328',
#   '3,638',
#   '71',
#   '9,429,113',
#   '74,719',
#   '126,193,621 ',
#   'Asia',
#   '27514,16613',
#   ''],
#  ['',
#   '40',
#   'Lebanon',
#   '448,721',
#   '',
#   '5,903 ',
#   '',
#   '350,694',
#   '',
#   '92,124',
#   '991',
#   '65,958',
#   '868',
#   '3,448,772',
#   '506,941',
#   '6,803,105 ',
#   'Asia',
#   '151,1522',
#   ''],
#  ['',
#   '41',
#   'UAE',
#   '448,637',
#   '+2,043',
#   '1,466 ',
#   '+10',
#   '431,773',
#   '+2,200',
#   '15,398',
#   '',
#   '44,966',
#   '147',
#   '36,247,630',
#   '3,633,062',
#   '9,977,157 ',
#   'Asia',
#   '226,8060',
#   ''],
#  ['',
#   '42',
#   'Saudi Arabia',
#   '386,300',
#   '',
#   '6,624 ',
#   '',
#   '375,471',
#   '',
#   '4,205',
#   '627',
#   '10,972',
#   '188',
#   '14,717,992',
#   '418,043',
#   '35,206,861 ',
#   'Asia',
#   '915,3152',
#   ''],
#  ['',
#   '43',
#   'Slovakia',
#   '354,182',
#   '+1,654',
#   '9,313 ',
#   '+52',
#   '255,300',
#   '',
#   '89,569',
#   '693',
#   '64,850',
#   '1,705',
#   '2,300,975',
#   '421,303',
#   '5,461,571 ',
#   'Europe',
#   '155862',
#   ''],
#  ['',
#   '44',
#   'Panama',
#   '352,082',
#   '',
#   '6,065 ',
#   '',
#   '340,974',
#   '',
#   '5,043',
#   '111',
#   '80,679',
#   '1,390',
#   '2,095,216',
#   '480,114',
#   '4,363,996 ',
#   'North America',
#   '127202',
#   ''],
#  ['',
#   '45',
#   'Malaysia',
#   '338,168',
#   '+1,360',
#   '1,248 ',
#   '+2',
#   '322,416',
#   '+1,491',
#   '14,504',
#   '157',
#   '10,352',
#   '38',
#   '7,372,592',
#   '225,690',
#   '32,666,960 ',
#   'Asia',
#   '9726,1754',
#   ''],
#  ['',
#   '46',
#   'Bulgaria',
#   '317,116',
#   '',
#   '12,413 ',
#   '',
#   '242,311',
#   '',
#   '62,392',
#   '743',
#   '45,891',
#   '1,796',
#   '2,006,166',
#   '290,321',
#   '6,910,172 ',
#   'Europe',
#   '225573',
#   ''],
#  ['',
#   '47',
#   'Ecuador',
#   '316,807',
#   '',
#   '16,540 ',
#   '',
#   '271,847',
#   '',
#   '28,420',
#   '506',
#   '17,761',
#   '927',
#   '1,111,805',
#   '62,330',
#   '17,837,279 ',
#   'South America',
#   '561,07816',
#   ''],
#  ['',
#   '48',
#   'Belarus',
#   '313,852',
#   '',
#   '2,184 ',
#   '',
#   '304,477',
#   '',
#   '7,191',
#   '',
#   '33,222',
#   '231',
#   '5,253,173',
#   '556,065',
#   '9,447,055 ',
#   'Europe',
#   '304,3262',
#   ''],
#  ['',
#   '49',
#   'Georgia',
#   '279,027',
#   '+399',
#   '3,732 ',
#   '+10',
#   '271,278',
#   '+356',
#   '4,017',
#   '',
#   '70,044',
#   '937',
#   '3,221,967',
#   '808,813',
#   '3,983,576 ',
#   'Asia',
#   '141,0671',
#   ''],
#  ['',
#   '50',
#   'Nepal',
#   '276,389',
#   '',
#   '3,020 ',
#   '',
#   '272,187',
#   '',
#   '1,182',
#   '',
#   '9,364',
#   '102',
#   '2,248,993',
#   '76,195',
#   '29,516,234 ',
#   'Asia',
#   '1079,77413',
#   ''],
#  ['',
#   '51',
#   'Bolivia',
#   '267,059',
#   '+973',
#   '12,107 ',
#   '+14',
#   '214,988',
#   '+1,209',
#   '39,964',
#   '71',
#   '22,654',
#   '1,027',
#   '866,360',
#   '73,492',
#   '11,788,539 ',
#   'South America',
#   '4497414',
#   ''],
#  ['',
#   '52',
#   'Croatia',
#   '262,309',
#   '+1,673',
#   '5,838 ',
#   '+10',
#   '248,064',
#   '+856',
#   '8,407',
#   '100',
#   '64,185',
#   '1,429',
#   '1,503,437',
#   '367,881',
#   '4,086,752 ',
#   'Europe',
#   '167003',
#   ''],
#  ['',
#   '53',
#   'Dominican Republic',
#   '250,579',
#   '',
#   '3,289 ',
#   '',
#   '209,586',
#   '',
#   '37,704',
#   '154',
#   '22,932',
#   '301',
#   '1,287,584',
#   '117,836',
#   '10,926,958 ',
#   'North America',
#   '443,3228',
#   ''],
#  ['',
#   '54',
#   'Azerbaijan',
#   '249,492',
#   '',
#   '3,404 ',
#   '',
#   '233,834',
#   '',
#   '12,254',
#   '',
#   '24,447',
#   '334',
#   '2,799,101',
#   '274,271',
#   '10,205,615 ',
#   'Asia',
#   '412,9984',
#   ''],
#  ['',
#   '55',
#   'Tunisia',
#   '247,254',
#   '',
#   '8,637 ',
#   '',
#   '213,969',
#   '',
#   '24,648',
#   '277',
#   '20,763',
#   '725',
#   '1,074,639',
#   '90,242',
#   '11,908,465 ',
#   'Africa',
#   '481,37911',
#   ''],
#  ['',
#   '56',
#   'Greece',
#   '245,405',
#   '',
#   '7,649 ',
#   '',
#   '209,436',
#   '',
#   '28,320',
#   '699',
#   '23,629',
#   '736',
#   '6,254,354',
#   '602,200',
#   '10,385,837 ',
#   'Europe',
#   '421,3582',
#   ''],
#  ['',
#   '57',
#   'Kazakhstan',
#   '236,200',
#   '+1,105',
#   '2,941 ',
#   '',
#   '213,743',
#   '+835',
#   '19,516',
#   '221',
#   '12,471',
#   '155',
#   '8,298,090',
#   '438,130',
#   '18,939,771 ',
#   'Asia',
#   '806,4402',
#   ''],
#  ['',
#   '58',
#   'Ireland',
#   '232,164',
#   '',
#   '4,628 ',
#   '',
#   '23,364',
#   '',
#   '204,172',
#   '75',
#   '46,639',
#   '930',
#   '3,879,162',
#   '779,285',
#   '4,977,846 ',
#   'Europe',
#   '211,0761',
#   ''],
#  ['',
#   '59',
#   'Palestine',
#   '230,076',
#   '',
#   '2,501 ',
#   '',
#   '203,340',
#   '',
#   '24,235',
#   '206',
#   '44,356',
#   '482',
#   '1,384,569',
#   '266,928',
#   '5,187,059 ',
#   'Asia',
#   '232,0744',
#   ''],
#  ['',
#   '60',
#   'Denmark',
#   '227,894',
#   '',
#   '2,405 ',
#   '',
#   '215,770',
#   '',
#   '9,719',
#   '46',
#   '39,244',
#   '414',
#   '23,267,463',
#   '4,006,751',
#   '5,807,065 ',
#   'Europe',
#   '252,4150',
#   ''],
#  ['',
#   '61',
#   'Kuwait',
#   '223,042',
#   '',
#   '1,256 ',
#   '',
#   '207,392',
#   '',
#   '14,394',
#   '238',
#   '51,674',
#   '291',
#   '1,994,656',
#   '462,115',
#   '4,316,367 ',
#   'Asia',
#   '193,4372',
#   ''],
#  ['',
#   '62',
#   'Moldova',
#   '219,988',
#   '',
#   '4,661 ',
#   '',
#   '193,562',
#   '',
#   '21,765',
#   '341',
#   '54,627',
#   '1,157',
#   '816,504',
#   '202,752',
#   '4,027,116 ',
#   'Europe',
#   '188645',
#   ''],
#  ['',
#   '63',
#   'Costa Rica',
#   '213,438',
#   '',
#   '2,908 ',
#   '',
#   '190,950',
#   '',
#   '19,580',
#   '147',
#   '41,623',
#   '567',
#   '775,821',
#   '151,293',
#   '5,127,933 ',
#   'North America',
#   '241,7637',
#   ''],
#  ['',
#   '64',
#   'Lithuania',
#   '211,804',
#   '+769',
#   '3,521 ',
#   '+4',
#   '196,067',
#   '+516',
#   '12,216',
#   '141',
#   '78,608',
#   '1,307',
#   '2,295,275',
#   '851,858',
#   '2,694,433 ',
#   'Europe',
#   '137651',
#   ''],
#  ['',
#   '65',
#   'Slovenia',
#   '209,753',
#   '+1,164',
#   '3,998 ',
#   '+4',
#   '194,238',
#   '+855',
#   '11,517',
#   '107',
#   '100,884',
#   '1,923',
#   '1,027,457',
#   '494,173',
#   '2,079,146 ',
#   'Europe',
#   '105202',
#   ''],
#  ['',
#   '66',
#   'Paraguay',
#   '200,823',
#   '',
#   '3,869 ',
#   '',
#   '164,401',
#   '',
#   '32,553',
#   '413',
#   '27,907',
#   '538',
#   '868,914',
#   '120,747',
#   '7,196,139 ',
#   'South America',
#   '361,8608',
#   ''],
#  ['',
#   '67',
#   'Egypt',
#   '197,350',
#   '',
#   '11,720 ',
#   '',
#   '151,444',
#   '',
#   '34,186',
#   '90',
#   '1,903',
#   '113',
#   '2,506,118',
#   '24,160',
#   '103,731,274 ',
#   'Africa',
#   '5268,85141',
#   ''],
#  ['',
#   '68',
#   'Ethiopia',
#   '192,575',
#   '',
#   '2,718 ',
#   '',
#   '150,642',
#   '',
#   '39,215',
#   '752',
#   '1,646',
#   '23',
#   '2,301,145',
#   '19,665',
#   '117,018,653 ',
#   'Africa',
#   '60843,05351',
#   ''],
#  ['',
#   '69',
#   'Guatemala',
#   '190,208',
#   '',
#   '6,749 ',
#   '',
#   '173,301',
#   '',
#   '10,158',
#   '5',
#   '10,477',
#   '372',
#   '1,023,093',
#   '56,352',
#   '18,155,455 ',
#   'North America',
#   '952,69018',
#   ''],
#  ['',
#   '70',
#   'Armenia',
#   '187,441',
#   '+1,257',
#   '3,416  ',
#   '+18',
#   '169,727',
#   '+242',
#   '14,298',
#   '',
#   '63,169',
#   '1,151',
#   '822,634',
#   '277,235',
#   '2,967,281 ',
#   'Asia',
#   '168694',
#   ''],
#  ['',
#   '71',
#   'Honduras',
#   '184,821',
#   '+790',
#   '4,506 ',
#   '+17',
#   '69,935',
#   '+477',
#   '110,380',
#   '461',
#   '18,447',
#   '450',
#   '499,931',
#   '49,899',
#   '10,018,773 ',
#   'North America',
#   '542,22320',
#   ''],
#  ['',
#   '72',
#   'Qatar',
#   '175,332',
#   '',
#   '278 ',
#   '',
#   '161,488',
#   '',
#   '13,566',
#   '224',
#   '62,445',
#   '99',
#   '1,686,747',
#   '600,735',
#   '2,807,805 ',
#   'Asia',
#   '1610,1002',
#   ''],
#  ['',
#   '73',
#   'Nigeria',
#   '162,178',
#   '',
#   '2,031 ',
#   '',
#   '148,726',
#   '',
#   '11,421',
#   '10',
#   '773',
#   '10',
#   '1,727,467',
#   '8,233',
#   '209,826,700 ',
#   'Africa',
#   '1,294103,312121',
#   ''],
#  ['',
#   '74',
#   'Bosnia and Herzegovina',
#   '158,198',
#   '',
#   '6,067 ',
#   '',
#   '127,247',
#   '',
#   '24,884',
#   '',
#   '48,439',
#   '1,858',
#   '758,540',
#   '232,261',
#   '3,265,894 ',
#   'Europe',
#   '215384',
#   ''],
#  ['',
#   '75',
#   'Libya',
#   '155,232',
#   '+912',
#   '2,591 ',
#   '+9',
#   '142,633',
#   '+1,220',
#   '10,008',
#   '',
#   '22,371',
#   '373',
#   '838,770',
#   '120,876',
#   '6,939,080 ',
#   'Africa',
#   '452,6788',
#   ''],
#  ['',
#   '76',
#   'Oman',
#   '153,838',
#   '+733',
#   '1,650 ',
#   '+6',
#   '140,766',
#   '+546',
#   '11,422',
#   '128',
#   '29,582',
#   '317',
#   '1,550,000',
#   '298,058',
#   '5,200,322 ',
#   'Asia',
#   '343,1523',
#   ''],
#  ['',
#   '77',
#   'Venezuela',
#   '153,315',
#   '',
#   '1,521 ',
#   '',
#   '142,381',
#   '',
#   '9,413',
#   '162',
#   '5,403',
#   '54',
#   '3,102,996',
#   '109,349',
#   '28,377,088 ',
#   'South America',
#   '18518,6579',
#   ''],
#  ['',
#   '78',
#   'Myanmar',
#   '142,315',
#   '+23',
#   '3,204 ',
#   '',
#   '131,774',
#   '+2',
#   '7,337',
#   '',
#   '2,603',
#   '59',
#   '2,528,779',
#   '46,251',
#   '54,675,230 ',
#   'Asia',
#   '38417,06522',
#   ''],
#  ['',
#   '79',
#   'Bahrain',
#   '138,283',
#   '',
#   '507 ',
#   '',
#   '130,397',
#   '',
#   '7,379',
#   '49',
#   '79,288',
#   '291',
#   '3,464,973',
#   '1,986,741',
#   '1,744,049 ',
#   'Asia',
#   '133,4401',
#   ''],
#  ['',
#   '80',
#   'Kenya',
#   '124,707',
#   '',
#   '2,066 ',
#   '',
#   '90,770',
#   '',
#   '31,871',
#   '141',
#   '2,283',
#   '38',
#   '1,434,725',
#   '26,264',
#   '54,627,198 ',
#   'Africa',
#   '43826,44138',
#   ''],
#  ['',
#   '81',
#   'Albania',
#   '122,295',
#   '',
#   '2,171 ',
#   '',
#   '87,193',
#   '',
#   '32,931',
#   '46',
#   '42,530',
#   '755',
#   '535,039',
#   '186,068',
#   '2,875,503 ',
#   'Europe',
#   '241,3255',
#   ''],
#  ['',
#   '82',
#   'North Macedonia',
#   '122,227',
#   '',
#   '3,545 ',
#   '',
#   '102,652',
#   '',
#   '16,030',
#   '124',
#   '58,670',
#   '1,702',
#   '599,782',
#   '287,898',
#   '2,083,312 ',
#   'Europe',
#   '175883',
#   ''],
#  ['',
#   '83',
#   'Algeria',
#   '116,438',
#   '',
#   '3,069 ',
#   '',
#   '81,065',
#   '',
#   '32,304',
#   '9',
#   '2,621',
#   '69',
#   '230,553',
#   '5,190',
#   '44,424,331 ',
#   'Africa',
#   '38214,475193',
#   ''],
#  ['',
#   '84',
#   'Estonia',
#   '100,437',
#   '+1,429',
#   '836 ',
#   '+13',
#   '71,376',
#   '+463',
#   '28,225',
#   '69',
#   '75,677',
#   '630',
#   '1,110,888',
#   '837,025',
#   '1,327,186 ',
#   'Europe',
#   '131,5881',
#   ''],
#  ['',
#   '85',
#   'S. Korea',
#   '100,276',
#   '+430',
#   '1,709 ',
#   '+2',
#   '92,068',
#   '+508',
#   '6,499',
#   '111',
#   '1,955',
#   '33',
#   '7,485,859',
#   '145,919',
#   '51,301,369 ',
#   'Asia',
#   '51230,0187',
#   ''],
#  ['',
#   '86',
#   'Latvia',
#   '98,870',
#   '',
#   '1,851 ',
#   '',
#   '89,910',
#   '',
#   '7,109',
#   '68',
#   '52,846',
#   '989',
#   '1,792,989',
#   '958,346',
#   '1,870,920 ',
#   'Europe',
#   '191,0111',
#   ''],
#  ['',
#   '87',
#   'Sri Lanka',
#   '91,018',
#   '',
#   '552 ',
#   '',
#   '87,630',
#   '',
#   '2,836',
#   '',
#   '4,238',
#   '26',
#   '2,352,000',
#   '109,504',
#   '21,478,652 ',
#   'Asia',
#   '23638,9119',
#   ''],
#  ['',
#   '88',
#   'Norway',
#   '90,104',
#   '',
#   '656 ',
#   '',
#   '74,332',
#   '',
#   '15,116',
#   '47',
#   '16,527',
#   '120',
#   '4,464,591',
#   '818,879',
#   '5,452,074 ',
#   'Europe',
#   '618,3111',
#   ''],
#  ['',
#   '89',
#   'Ghana',
#   '89,893',
#   '',
#   '734 ',
#   '',
#   '86,248',
#   '',
#   '2,911',
#   '47',
#   '2,850',
#   '23',
#   '975,812',
#   '30,937',
#   '31,541,905 ',
#   'Africa',
#   '35142,97332',
#   ''],
#  ['',
#   '90',
#   'Montenegro',
#   '88,550',
#   '',
#   '1,224 ',
#   '',
#   '79,634',
#   '',
#   '7,692',
#   '69',
#   '140,975',
#   '1,949',
#   '326,962',
#   '520,537',
#   '628,124 ',
#   'Europe',
#   '75132',
#   ''],
#  ['',
#   '91',
#   'Uruguay',
#   '87,812',
#   '',
#   '843 ',
#   '',
#   '71,588',
#   '',
#   '15,381',
#   '225',
#   '25,215',
#   '242',
#   '1,264,894',
#   '363,214',
#   '3,482,502 ',
#   'South America',
#   '404,1313',
#   ''],
#  ['',
#   '92',
#   'Kyrgyzstan',
#   '87,758',
#   '+106',
#   '1,494 ',
#   '+2',
#   '84,407',
#   '+68',
#   '1,857',
#   '16',
#   '13,292',
#   '226',
#   '827,068',
#   '125,272',
#   '6,602,182 ',
#   'Asia',
#   '754,4198',
#   ''],
#  ['',
#   '93',
#   'Zambia',
#   '86,993',
#   '',
#   '1,187 ',
#   '',
#   '83,617',
#   '',
#   '2,189',
#   '119',
#   '4,638',
#   '63',
#   '1,211,098',
#   '64,575',
#   '18,754,924 ',
#   'Africa',
#   '21615,80015',
#   ''],
#  ['',
#   '94',
#   'Uzbekistan',
#   '81,816',
#   '+138',
#   '624 ',
#   '+1',
#   '80,143',
#   '+98',
#   '1,049',
#   '23',
#   '2,419',
#   '18',
#   '1,377,915',
#   '40,741',
#   '33,820,969 ',
#   'Asia',
#   '41354,20025',
#   ''],
#  ['',
#   '95',
#   'Finland',
#   '74,242',
#   '+726',
#   '815 ',
#   '+4',
#   '46,000',
#   '',
#   '27,427',
#   '59',
#   '13,384',
#   '147',
#   '3,843,882',
#   '692,966',
#   '5,546,997 ',
#   'Europe',
#   '756,8061',
#   ''],
#  ['',
#   '96',
#   'Cuba',
#   '68,986',
#   '',
#   '405 ',
#   '',
#   '65,177',
#   '',
#   '3,404',
#   '67',
#   '6,093',
#   '36',
#   '2,843,469',
#   '251,155',
#   '11,321,570 ',
#   'North America',
#   '16427,9544',
#   ''],
#  ['',
#   '97',
#   'Mozambique',
#   '66,649',
#   '',
#   '752 ',
#   '',
#   '53,803',
#   '',
#   '12,094',
#   '',
#   '2,090',
#   '24',
#   '469,425',
#   '14,722',
#   '31,886,376 ',
#   'Africa',
#   '47842,40268',
#   ''],
#  ['',
#   '98',
#   'El Salvador',
#   '63,766',
#   '',
#   '1,990 ',
#   '',
#   '61,009',
#   '',
#   '767',
#   '35',
#   '9,795',
#   '306',
#   '827,129',
#   '127,054',
#   '6,510,037 ',
#   'North America',
#   '1023,2718',
#   ''],
#  ['',
#   '99',
#   'Singapore',
#   '60,253',
#   '+17',
#   '30 ',
#   '',
#   '60,078',
#   '',
#   '145',
#   '',
#   '10,240',
#   '5',
#   '8,307,697',
#   '1,411,959',
#   '5,883,807 ',
#   'Asia',
#   '98196,1271',
#   ''],
#  ['',
#   '100',
#   'Luxembourg',
#   '59,907',
#   '',
#   '728 ',
#   '',
#   '55,842',
#   '',
#   '3,337',
#   '17',
#   '94,586',
#   '1,149',
#   '2,330,526',
#   '3,679,640',
#   '633,357 ',
#   'Europe',
#   '118700',
#   ''],
#  ['',
#   '101',
#   'Afghanistan',
#   '56,254',
#   '+28',
#   '2,469 ',
#   '+2',
#   '49,937',
#   '+135',
#   '3,848',
#   '1,105',
#   '1,422',
#   '62',
#   '337,560',
#   '8,532',
#   '39,561,728 ',
#   'Asia',
#   '70316,023117',
#   ''],
#  ['',
#   '102',
#   'Cyprus',
#   '43,286',
#   '',
#   '248 ',
#   '',
#   '2,057',
#   '',
#   '40,981',
#   '47',
#   '35,663',
#   '204',
#   '2,994,813',
#   '2,467,399',
#   '1,213,753 ',
#   'Asia',
#   '284,8940',
#   ''],
#  ['',
#   '103',
#   'Namibia',
#   '42,864',
#   '',
#   '502 ',
#   '',
#   '39,976',
#   '',
#   '2,386',
#   '30',
#   '16,651',
#   '195',
#   '336,638',
#   '130,773',
#   '2,574,219 ',
#   'Africa',
#   '605,1288',
#   ''],
#  ['',
#   '104',
#   'Ivory Coast',
#   '41,307',
#   '',
#   '224 ',
#   '',
#   '37,320',
#   '',
#   '3,763',
#   '',
#   '1,538',
#   '8',
#   '492,562',
#   '18,345',
#   '26,849,670 ',
#   'Africa',
#   '650119,86555',
#   ''],
#  ['',
#   '105',
#   'Uganda',
#   '40,719',
#   '',
#   '334 ',
#   '',
#   '15,139',
#   '',
#   '25,246',
#   '',
#   '870',
#   '7',
#   '922,290',
#   '19,715',
#   '46,780,009 ',
#   'Africa',
#   '1,149140,06051',
#   ''],
#  ['',
#   '106',
#   'Cameroon',
#   '40,622',
#   '',
#   '601 ',
#   '',
#   '35,261',
#   '',
#   '4,760',
#   '53',
#   '1,503',
#   '22',
#   '905,000',
#   '33,490',
#   '27,022,703 ',
#   'Africa',
#   '66544,96330',
#   ''],
#  ['',
#   '107',
#   'Senegal',
#   '38,255',
#   '+121',
#   '1,028 ',
#   '+5',
#   '35,811',
#   '+303',
#   '1,416',
#   '38',
#   '2,242',
#   '60',
#   '430,703',
#   '25,243',
#   '17,062,110 ',
#   'Africa',
#   '44616,59740',
#   ''],
#  ['',
#   '108',
#   'Botswana',
#   '37,559',
#   '',
#   '485 ',
#   '',
#   '32,550',
#   '',
#   '4,524',
#   '1',
#   '15,742',
#   '203',
#   '901,776',
#   '377,950',
#   '2,385,969 ',
#   'Africa',
#   '644,9203',
#   ''],
#  ['',
#   '109',
#   'Zimbabwe',
#   '36,749',
#   '',
#   '1,516  ',
#   '',
#   '34,476',
#   '',
#   '757',
#   '13',
#   '2,447',
#   '101',
#   '370,420',
#   '24,662',
#   '15,019,826 ',
#   'Africa',
#   '4099,90841',
#   ''],
#  ['',
#   '110',
#   'Jamaica',
#   '36,670',
#   '',
#   '545 ',
#   '',
#   '16,618',
#   '',
#   '19,507',
#   '42',
#   '12,344',
#   '183',
#   '267,792',
#   '90,148',
#   '2,970,581 ',
#   'North America',
#   '815,45111',
#   ''],
#  ['',
#   '111',
#   'Malawi',
#   '33,354',
#   '',
#   '1,105 ',
#   '',
#   '29,253',
#   '',
#   '2,996',
#   '31',
#   '1,712',
#   '57',
#   '214,525',
#   '11,009',
#   '19,486,504 ',
#   'Africa',
#   '58417,63591',
#   ''],
#  ['',
#   '112',
#   'Sudan',
#   '29,661',
#   '',
#   '2,028 ',
#   '',
#   '23,990',
#   '',
#   '3,643',
#   '',
#   '665',
#   '45',
#   '',
#   '',
#   '44,588,619 ',
#   'Africa',
#   '1,50321,986',
#   ''],
#  ['',
#   '113',
#   'Australia',
#   '29,228',
#   '+10',
#   '909 ',
#   '',
#   '26,257',
#   '+4',
#   '2,062',
#   '',
#   '1,137',
#   '35',
#   '15,327,694',
#   '596,067',
#   '25,714,728 ',
#   'Australia/Oceania',
#   '88028,2892',
#   ''],
#  ['',
#   '114',
#   'Malta',
#   '28,510',
#   '',
#   '377 ',
#   '',
#   '25,857',
#   '',
#   '2,276',
#   '',
#   '64,444',
#   '852',
#   '792,598',
#   '1,791,587',
#   '442,400 ',
#   'Europe',
#   '161,1731',
#   ''],
#  ['',
#   '115',
#   'Thailand',
#   '28,443',
#   '+97',
#   '92 ',
#   '',
#   '26,946',
#   '+73',
#   '1,405',
#   '1',
#   '407',
#   '1',
#   '8,014,926',
#   '114,617',
#   '69,927,651 ',
#   'Asia',
#   '2,459760,0839',
#   ''],
#  ['',
#   '116',
#   'DRC',
#   '27,729',
#   '+69',
#   '726 ',
#   '',
#   '25,355',
#   '+69',
#   '1,648',
#   '',
#   '303',
#   '8',
#   '',
#   '',
#   '91,520,972 ',
#   'Africa',
#   '3,301126,062',
#   ''],
#  ['',
#   '117',
#   'Madagascar',
#   '23,040',
#   '+196',
#   '369 ',
#   '+6',
#   '21,372',
#   '+90',
#   '1,299',
#   '23',
#   '817',
#   '13',
#   '137,929',
#   '4,890',
#   '28,204,522 ',
#   'Africa',
#   '1,22476,435204',
#   ''],
#  ['',
#   '118',
#   'Maldives',
#   '22,929',
#   '',
#   '66 ',
#   '',
#   '20,359',
#   '',
#   '2,504',
#   '102',
#   '41,884',
#   '121',
#   '623,614',
#   '1,139,150',
#   '547,438 ',
#   'Asia',
#   '248,2951',
#   ''],
#  ['',
#   '119',
#   'Angola',
#   '21,836',
#   '',
#   '532 ',
#   '',
#   '20,172',
#   '',
#   '1,132',
#   '18',
#   '650',
#   '16',
#   '412,654',
#   '12,281',
#   '33,601,788 ',
#   'Africa',
#   '1,53963,16181',
#   ''],
#  ['',
#   '120',
#   'Rwanda',
#   '21,106',
#   '',
#   '297 ',
#   '',
#   '19,441',
#   '',
#   '1,368',
#   '1',
#   '1,601',
#   '23',
#   '1,098,629',
#   '83,331',
#   '13,183,921 ',
#   'Africa',
#   '62544,39012',
#   ''],
#  ['',
#   '121',
#   'Guinea',
#   '19,232',
#   '+148',
#   '113 ',
#   '',
#   '16,190',
#   '+58',
#   '2,929',
#   '24',
#   '1,436',
#   '8',
#   '171,746',
#   '12,827',
#   '13,389,574 ',
#   'Africa',
#   '696118,49278',
#   ''],
#  ['',
#   '122',
#   'Mayotte',
#   '19,224',
#   '',
#   '154 ',
#   '',
#   '2,964',
#   '',
#   '16,106',
#   '16',
#   '69,259',
#   '555',
#   '147,985',
#   '533,151',
#   '277,567 ',
#   'Africa',
#   '141,8022',
#   ''],
#  ['',
#   '123',
#   'French Polynesia',
#   '18,598',
#   '',
#   '141 ',
#   '',
#   '4,842',
#   '',
#   '13,615',
#   '2',
#   '65,929',
#   '500',
#   '26,355',
#   '93,428',
#   '282,090 ',
#   'Australia/Oceania',
#   '152,00111',
#   ''],
#  ['',
#   '124',
#   'Gabon',
#   '18,426',
#   '',
#   '109 ',
#   '',
#   '15,863',
#   '',
#   '2,454',
#   '33',
#   '8,140',
#   '48',
#   '613,559',
#   '271,048',
#   '2,263,656 ',
#   'Africa',
#   '12320,7674',
#   ''],
#  ['',
#   '125',
#   'Syria',
#   '17,896',
#   '',
#   '1,195 ',
#   '',
#   '11,907',
#   '',
#   '4,794',
#   '',
#   '1,005',
#   '67',
#   '',
#   '',
#   '17,807,533 ',
#   'Asia',
#   '99514,902',
#   ''],
#  ['',
#   '126',
#   'Mauritania',
#   '17,690',
#   '',
#   '447 ',
#   '',
#   '16,947',
#   '',
#   '296',
#   '14',
#   '3,734',
#   '94',
#   '196,596',
#   '41,495',
#   '4,737,793 ',
#   'Africa',
#   '26810,59924',
#   ''],
#  ['',
#   '127',
#   'Eswatini',
#   '17,301',
#   '',
#   '666 ',
#   '',
#   '16,175',
#   '',
#   '460',
#   '36',
#   '14,801',
#   '570',
#   '169,393',
#   '144,918',
#   '1,168,892 ',
#   'Africa',
#   '681,7557',
#   ''],
#  ['',
#   '128',
#   'French Guiana',
#   '16,922',
#   '',
#   '89 ',
#   '',
#   '9,995',
#   '',
#   '6,838',
#   '6',
#   '55,616',
#   '293',
#   '158,139',
#   '519,739',
#   '304,266 ',
#   'South America',
#   '183,4192',
#   ''],
#  ['',
#   '129',
#   'Cabo Verde',
#   '16,661',
#   '',
#   '163 ',
#   '',
#   '15,889',
#   '',
#   '609',
#   '23',
#   '29,732',
#   '291',
#   '125,300',
#   '223,601',
#   '560,373 ',
#   'Africa',
#   '343,4384',
#   ''],
#  ['',
#   '130',
#   'Réunion',
#   '15,561',
#   '',
#   '102 ',
#   '',
#   '14,064',
#   '',
#   '1,395',
#   '57',
#   '17,291',
#   '113',
#   '98,785',
#   '109,766',
#   '899,961 ',
#   'Africa',
#   '588,8239',
#   ''],
#  ['',
#   '132',
#   'Haiti',
#   '12,732',
#   '',
#   '251 ',
#   '',
#   '10,754',
#   '',
#   '1,727',
#   '',
#   '1,107',
#   '22',
#   '54,379',
#   '4,727',
#   '11,503,439 ',
#   'North America',
#   '90445,830212',
#   ''],
#  ['',
#   '133',
#   'Burkina Faso',
#   '12,596',
#   '',
#   '145 ',
#   '',
#   '12,269',
#   '',
#   '182',
#   '',
#   '591',
#   '7',
#   '',
#   '',
#   '21,316,388 ',
#   'Africa',
#   '1,692147,010',
#   ''],
#  ['',
#   '134',
#   'Belize',
#   '12,410',
#   '',
#   '317 ',
#   '',
#   '12,047',
#   '',
#   '46',
#   '',
#   '30,805',
#   '787',
#   '95,541',
#   '237,160',
#   '402,854 ',
#   'North America',
#   '321,2714',
#   ''],
#  ['',
#   '135',
#   'Andorra',
#   '11,638',
#   '',
#   '114 ',
#   '',
#   '11,082',
#   '',
#   '442',
#   '12',
#   '150,449',
#   '1,474',
#   '193,595',
#   '2,502,682',
#   '77,355 ',
#   'Europe',
#   '76790',
#   ''],
#  ['',
#   '136',
#   'Hong Kong',
#   '11,429',
#   '+9',
#   '204 ',
#   '',
#   '10,963',
#   '',
#   '262',
#   '10',
#   '1,516',
#   '27',
#   '9,296,529',
#   '1,232,763',
#   '7,541,215 ',
#   'Asia',
#   '66036,9671',
#   ''],
#  ['',
#   '137',
#   'Guadeloupe',
#   '11,298',
#   '',
#   '165 ',
#   '',
#   '2,242',
#   '',
#   '8,891',
#   '8',
#   '28,233',
#   '412',
#   '149,795',
#   '374,325',
#   '400,174 ',
#   'North America',
#   '352,4253',
#   ''],
#  ['',
#   '138',
#   'Lesotho',
#   '10,686',
#   '',
#   '315 ',
#   '',
#   '4,438',
#   '',
#   '5,933',
#   '',
#   '4,960',
#   '146',
#   '65,807',
#   '30,543',
#   '2,154,601 ',
#   'Africa',
#   '2026,84033',
#   ''],
#  ['',
#   '139',
#   'Somalia',
#   '10,369',
#   '',
#   '453 ',
#   '',
#   '4,564',
#   '',
#   '5,352',
#   '',
#   '640',
#   '28',
#   '',
#   '',
#   '16,212,726 ',
#   'Africa',
#   '1,56435,790',
#   ''],
#  ['',
#   '140',
#   'South Sudan',
#   '9,969',
#   '',
#   '107 ',
#   '',
#   '9,002',
#   '',
#   '860',
#   '1',
#   '883',
#   '9',
#   '127,025',
#   '11,252',
#   '11,289,017 ',
#   'Africa',
#   '1,132105,50589',
#   ''],
#  ['',
#   '141',
#   'Guyana',
#   '9,820',
#   '',
#   '220 ',
#   '',
#   '8,632',
#   '',
#   '968',
#   '12',
#   '12,441',
#   '279',
#   '84,486',
#   '107,037',
#   '789,316 ',
#   'South America',
#   '803,5889',
#   ''],
#  ['',
#   '142',
#   'Congo',
#   '9,681',
#   '',
#   '135 ',
#   '',
#   '7,514',
#   '',
#   '2,032',
#   '',
#   '1,724',
#   '24',
#   '92,500',
#   '16,470',
#   '5,616,113 ',
#   'Africa',
#   '58041,60161',
#   ''],
#  ['',
#   '143',
#   'Mali',
#   '9,577',
#   '',
#   '372 ',
#   '',
#   '6,680',
#   '',
#   '2,525',
#   '',
#   '463',
#   '18',
#   '159,785',
#   '7,730',
#   '20,670,941 ',
#   'Africa',
#   '2,15855,567129',
#   ''],
#  ['',
#   '144',
#   'Togo',
#   '9,340',
#   '+193',
#   '105 ',
#   '',
#   '7,400',
#   '+59',
#   '1,835',
#   '',
#   '1,109',
#   '12',
#   '265,010',
#   '31,478',
#   '8,418,839 ',
#   'Africa',
#   '90180,17932',
#   ''],
#  ['',
#   '145',
#   'Suriname',
#   '9,077',
#   '',
#   '177 ',
#   '',
#   '8,568',
#   '',
#   '332',
#   '2',
#   '15,373',
#   '300',
#   '44,069',
#   '74,636',
#   '590,453 ',
#   'South America',
#   '653,33613',
#   ''],
#  ['',
#   '146',
#   'Aruba',
#   '8,985',
#   '',
#   '82 ',
#   '',
#   '8,336',
#   '',
#   '567',
#   '8',
#   '83,897',
#   '766',
#   '120,462',
#   '1,124,804',
#   '107,096 ',
#   'North America',
#   '121,3061',
#   ''],
#  ['',
#   '147',
#   'Bahamas',
#   '8,935',
#   '',
#   '188 ',
#   '',
#   '7,757',
#   '',
#   '990',
#   '3',
#   '22,565',
#   '475',
#   '73,721',
#   '186,176',
#   '395,975 ',
#   'North America',
#   '442,1065',
#   ''],
#  ['',
#   '148',
#   'Trinidad and Tobago',
#   '7,903',
#   '',
#   '141 ',
#   '',
#   '7,575',
#   '',
#   '187',
#   '12',
#   '5,634',
#   '101',
#   '108,872',
#   '77,611',
#   '1,402,791 ',
#   'North America',
#   '1789,94913',
#   ''],
#  ['',
#   '149',
#   'Martinique',
#   '7,710',
#   '',
#   '49 ',
#   '',
#   '98',
#   '',
#   '7,563',
#   '5',
#   '20,557',
#   '131',
#   '118,816',
#   '316,798',
#   '375,053 ',
#   'North America',
#   '497,6543',
#   ''],
#  ['',
#   '150',
#   'Benin',
#   '7,100',
#   '',
#   '90 ',
#   '',
#   '5,552',
#   '',
#   '1,458',
#   '35',
#   '575',
#   '7',
#   '521,218',
#   '42,196',
#   '12,352,199 ',
#   'Africa',
#   '1,740137,24724',
#   ''],
#  ['',
#   '151',
#   'Djibouti',
#   '6,895',
#   '',
#   '64 ',
#   '',
#   '6,172',
#   '',
#   '659',
#   '',
#   '6,906',
#   '64',
#   '124,729',
#   '124,927',
#   '998,419 ',
#   'Africa',
#   '14515,6008',
#   ''],
#  ['',
#   '152',
#   'Equatorial Guinea',
#   '6,851',
#   '',
#   '102 ',
#   '',
#   '6,335',
#   '',
#   '414',
#   '10',
#   '4,771',
#   '71',
#   '106,588',
#   '74,220',
#   '1,436,117 ',
#   'Africa',
#   '21014,08013',
#   ''],
#  ['',
#   '153',
#   'Nicaragua',
#   '6,629',
#   '',
#   '177 ',
#   '',
#   '4,225',
#   '',
#   '2,227',
#   '',
#   '992',
#   '26',
#   '',
#   '',
#   '6,681,779 ',
#   'North America',
#   '1,00837,750',
#   ''],
#  ['',
#   '154',
#   'Curaçao',
#   '6,424',
#   '',
#   '27 ',
#   '',
#   '4,952',
#   '',
#   '1,445',
#   '38',
#   '39,032',
#   '164',
#   '62,015',
#   '376,803',
#   '164,582 ',
#   'North America',
#   '266,0963',
#   ''],
#  ['',
#   '155',
#   'Iceland',
#   '6,144',
#   '',
#   '29 ',
#   '',
#   '6,040',
#   '',
#   '75',
#   '1',
#   '17,920',
#   '85',
#   '527,579',
#   '1,538,782',
#   '342,855 ',
#   'Europe',
#   '5611,8231',
#   ''],
#  ['',
#   '156',
#   'Mongolia',
#   '5,895',
#   '+285',
#   '5 ',
#   '',
#   '4,044',
#   '+97',
#   '1,846',
#   '22',
#   '1,777',
#   '2',
#   '2,159,400',
#   '651,099',
#   '3,316,547 ',
#   'Asia',
#   '563663,3092',
#   ''],
#  ['',
#   '157',
#   'Gambia',
#   '5,303',
#   '',
#   '161 ',
#   '',
#   '4,926',
#   '',
#   '216',
#   '3',
#   '2,151',
#   '65',
#   '53,586',
#   '21,734',
#   '2,465,585 ',
#   'Africa',
#   '46515,31446',
#   ''],
#  ['',
#   '158',
#   'CAR',
#   '5,088',
#   '',
#   '64 ',
#   '',
#   '4,957',
#   '',
#   '67',
#   '2',
#   '1,040',
#   '13',
#   '38,422',
#   '7,856',
#   '4,890,583 ',
#   'Africa',
#   '96176,415127',
#   ''],
#  ['',
#   '159',
#   'Niger',
#   '4,939',
#   '',
#   '185 ',
#   '',
#   '4,553',
#   '',
#   '201',
#   '1',
#   '199',
#   '7',
#   '86,912',
#   '3,500',
#   '24,835,440 ',
#   'Africa',
#   '5,028134,246286',
#   ''],
#  ['',
#   '160',
#   'San Marino',
#   '4,484',
#   '',
#   '82 ',
#   '',
#   '3,914',
#   '',
#   '488',
#   '9',
#   '131,948',
#   '2,413',
#   '51,114',
#   '1,504,105',
#   '33,983 ',
#   'Europe',
#   '84141',
#   ''],
#  ['',
#   '161',
#   'Chad',
#   '4,453',
#   '',
#   '158 ',
#   '',
#   '4,072',
#   '',
#   '223',
#   '',
#   '266',
#   '9',
#   '',
#   '',
#   '16,765,361 ',
#   'Africa',
#   '3,765106,110',
#   ''],
#  ['',
#   '162',
#   'Gibraltar',
#   '4,271',
#   '',
#   '94 ',
#   '',
#   '4,160',
#   '',
#   '17',
#   '1',
#   '126,796',
#   '2,791',
#   '208,125',
#   '6,178,750',
#   '33,684 ',
#   'Europe',
#   '83580',
#   ''],
#  ['',
#   '163',
#   'Saint Lucia',
#   '4,161',
#   '',
#   '58 ',
#   '',
#   '3,977',
#   '',
#   '126',
#   '2',
#   '22,585',
#   '315',
#   '35,015',
#   '190,053',
#   '184,238 ',
#   'North America',
#   '443,1775',
#   ''],
#  ['',
#   '164',
#   'Papua New Guinea',
#   '4,109',
#   '',
#   '39 ',
#   '',
#   '846',
#   '',
#   '3,224',
#   '',
#   '453',
#   '4',
#   '55,411',
#   '6,109',
#   '9,069,676 ',
#   'Australia/Oceania',
#   '2,207232,556164',
#   ''],
#  ['',
#   '166',
#   'Sierra Leone',
#   '3,953',
#   '',
#   '79 ',
#   '',
#   '2,796',
#   '',
#   '1,078',
#   '',
#   '488',
#   '10',
#   '116,448',
#   '14,386',
#   '8,094,302 ',
#   'Africa',
#   '2,048102,46070',
#   ''],
#  ['',
#   '167',
#   'Seychelles',
#   '3,882',
#   '',
#   '18 ',
#   '',
#   '3,318',
#   '',
#   '546',
#   '',
#   '39,295',
#   '182',
#   '5,200',
#   '52,637',
#   '98,790 ',
#   'Africa',
#   '255,48819',
#   ''],
#  ['',
#   '168',
#   'Yemen',
#   '3,703',
#   '',
#   '800 ',
#   '',
#   '1,577',
#   '',
#   '1,326',
#   '23',
#   '122',
#   '26',
#   '17,544',
#   '579',
#   '30,300,654 ',
#   'Asia',
#   '8,18337,8761,727',
#   ''],
#  ['',
#   '169',
#   'Comoros',
#   '3,682',
#   '',
#   '146 ',
#   '',
#   '3,491',
#   '',
#   '45',
#   '',
#   '4,170',
#   '165',
#   '',
#   '',
#   '882,992 ',
#   'Africa',
#   '2406,048',
#   ''],
#  ['',
#   '170',
#   'Guinea-Bissau',
#   '3,591',
#   '',
#   '56 ',
#   '',
#   '2,901',
#   '',
#   '634',
#   '16',
#   '1,794',
#   '28',
#   '57,291',
#   '28,623',
#   '2,001,587 ',
#   'Africa',
#   '55735,74335',
#   ''],
#  ['',
#   '171',
#   'Barbados',
#   '3,582',
#   '',
#   '40 ',
#   '',
#   '3,401',
#   '',
#   '141',
#   '',
#   '12,453',
#   '139',
#   '137,567',
#   '478,274',
#   '287,632 ',
#   'North America',
#   '807,1912',
#   ''],
#  ['',
#   '172',
#   'Eritrea',
#   '3,183',
#   '',
#   '8 ',
#   '',
#   '2,962',
#   '',
#   '213',
#   '',
#   '889',
#   '2',
#   '23,693',
#   '6,614',
#   '3,582,027 ',
#   'Africa',
#   '1,125447,753151',
#   ''],
#  ['',
#   '173',
#   'Burundi',
#   '2,657',
#   '',
#   '6 ',
#   '',
#   '773',
#   '',
#   '1,878',
#   '',
#   '219',
#   '0.5',
#   '90,019',
#   '7,412',
#   '12,145,730 ',
#   'Africa',
#   '4,5712,024,288135',
#   ''],
#  ['',
#   '174',
#   'Liechtenstein',
#   '2,636',
#   '',
#   '56 ',
#   '',
#   '2,548',
#   '',
#   '32',
#   '',
#   '68,991',
#   '1,466',
#   '29,848',
#   '781,198',
#   '38,208 ',
#   'Europe',
#   '146821',
#   ''],
#  ['',
#   '175',
#   'Vietnam',
#   '2,576',
#   '',
#   '35 ',
#   '',
#   '2,265',
#   '',
#   '276',
#   '',
#   '26',
#   '0.4',
#   '2,598,753',
#   '26,525',
#   '97,975,281 ',
#   'Asia',
#   '38,0342,799,29438',
#   ''],
#  ['',
#   '176',
#   'New Zealand',
#   '2,476',
#   '+6',
#   '26 ',
#   '',
#   '2,379',
#   '+2',
#   '71',
#   '',
#   '495',
#   '5',
#   '1,867,966',
#   '373,436',
#   '5,002,100 ',
#   'Australia/Oceania',
#   '2,020192,3883',
#   ''],
#  ['',
#   '177',
#   'Turks and Caicos',
#   '2,315',
#   '',
#   '17 ',
#   '',
#   '2,183',
#   '',
#   '115',
#   '2',
#   '59,212',
#   '435',
#   '20,896',
#   '534,466',
#   '39,097 ',
#   'North America',
#   '172,3002',
#   ''],
#  ['',
#   '178',
#   'Monaco',
#   '2,210',
#   '',
#   '28  ',
#   '',
#   '2,040',
#   '',
#   '142',
#   '3',
#   '56,029',
#   '710',
#   '51,953',
#   '1,317,133',
#   '39,444 ',
#   'Europe',
#   '181,4091',
#   ''],
#  ['',
#   '179',
#   'Sao Tome and Principe',
#   '2,174',
#   '',
#   '34 ',
#   '',
#   '2,015',
#   '',
#   '125',
#   '',
#   '9,788',
#   '153',
#   '11,592',
#   '52,192',
#   '222,105 ',
#   'Africa',
#   '1026,53319',
#   ''],
#  ['',
#   '180',
#   'Sint Maarten',
#   '2,114',
#   '',
#   '27 ',
#   '',
#   '2,062',
#   '',
#   '25',
#   '1',
#   '48,902',
#   '625',
#   '22,989',
#   '531,796',
#   '43,229 ',
#   'North America',
#   '201,6012',
#   ''],
#  ['',
#   '181',
#   'Liberia',
#   '2,042',
#   '',
#   '85 ',
#   '',
#   '1,899',
#   '',
#   '58',
#   '2',
#   '397',
#   '17',
#   '79,684',
#   '15,492',
#   '5,143,521 ',
#   'Africa',
#   '2,51960,51265',
#   ''],
#  ['',
#   '182',
#   'Cambodia',
#   '1,872',
#   '+55',
#   '5 ',
#   '',
#   '1,056',
#   '+23',
#   '811',
#   '',
#   '111',
#   '0.3',
#   '654,809',
#   '38,776',
#   '16,886,814 ',
#   'Asia',
#   '9,0213,377,36326',
#   ''],
#  ['',
#   '183',
#   'St. Vincent Grenadines',
#   '1,715',
#   '+12',
#   '10 ',
#   '',
#   '1,535',
#   '+6',
#   '170',
#   '2',
#   '15,423',
#   '90',
#   '40,268',
#   '362,132',
#   '111,197 ',
#   'North America',
#   '6511,1203',
#   ''],
#  ['',
#   '184',
#   'Saint Martin',
#   '1,619',
#   '',
#   '12 ',
#   '',
#   '1,399',
#   '',
#   '208',
#   '7',
#   '41,360',
#   '307',
#   '23,812',
#   '608,318',
#   '39,144 ',
#   'North America',
#   '243,2622',
#   ''],
#  ['',
#   '185',
#   'Isle of Man',
#   '1,530',
#   '',
#   '26 ',
#   '',
#   '702',
#   '',
#   '802',
#   '12',
#   '17,924',
#   '305',
#   '42,077',
#   '492,930',
#   '85,361 ',
#   'Europe',
#   '563,2832',
#   ''],
#  ['',
#   '186',
#   'Caribbean Netherlands',
#   '1,192',
#   '',
#   '10 ',
#   '',
#   '727',
#   '',
#   '455',
#   '',
#   '45,152',
#   '379',
#   '8,774',
#   '332,348',
#   '26,400 ',
#   'North America',
#   '222,6403',
#   ''],
#  ['',
#   '187',
#   'Antigua and Barbuda',
#   '1,100',
#   '+20',
#   '28 ',
#   '',
#   '743',
#   '+28',
#   '329',
#   '45',
#   '11,165',
#   '284',
#   '16,190',
#   '164,334',
#   '98,519 ',
#   'North America',
#   '903,5196',
#   ''],
#  ['',
#   '188',
#   'Taiwan',
#   '1,012',
#   '+3',
#   '10 ',
#   '',
#   '971',
#   '+2',
#   '31',
#   '',
#   '42',
#   '0.4',
#   '459,223',
#   '19,256',
#   '23,848,207 ',
#   'Asia',
#   '23,5652,384,82152',
#   ''],
#  ['',
#   '189',
#   'Bhutan',
#   '870',
#   '',
#   '1 ',
#   '',
#   '867',
#   '',
#   '2',
#   '',
#   '1,119',
#   '1',
#   '578,215',
#   '743,418',
#   '777,779 ',
#   'Asia',
#   '894777,7791',
#   ''],
#  ['',
#   '190',
#   'Mauritius',
#   '850',
#   '',
#   '10 ',
#   '',
#   '592',
#   '',
#   '248',
#   '',
#   '668',
#   '8',
#   '289,552',
#   '227,402',
#   '1,273,307 ',
#   'Africa',
#   '1,498127,3314',
#   ''],
#  ['',
#   '191',
#   'Bermuda',
#   '840',
#   '',
#   '12 ',
#   '',
#   '715',
#   '',
#   '113',
#   '',
#   '13,524',
#   '193',
#   '189,077',
#   '3,044,228',
#   '62,110 ',
#   'North America',
#   '745,1760',
#   ''],
#  ['',
#   '192',
#   'St. Barth',
#   '775',
#   '',
#   '1 ',
#   '',
#   '462',
#   '',
#   '312',
#   '',
#   '78,291',
#   '101',
#   '21,651',
#   '2,187,191',
#   '9,899 ',
#   'North America',
#   '139,8990',
#   ''],
#  ['',
#   '195',
#   'Tanzania',
#   '509',
#   '',
#   '21 ',
#   '',
#   '183',
#   '',
#   '305',
#   '7',
#   '8',
#   '0.3',
#   '',
#   '',
#   '60,959,861 ',
#   'Africa',
#   '119,7642,902,851',
#   ''],
#  ['',
#   '196',
#   'Cayman Islands',
#   '482',
#   '',
#   '2 ',
#   '',
#   '454',
#   '+5',
#   '26',
#   '',
#   '7,272',
#   '30',
#   '80,080',
#   '1,208,171',
#   '66,282 ',
#   'North America',
#   '13833,1411',
#   ''],
#  ['',
#   '197',
#   'Timor-Leste',
#   '394',
#   '+22',
#   ' ',
#   '',
#   '137',
#   '+12',
#   '257',
#   '',
#   '295',
#   '',
#   '37,974',
#   '28,411',
#   '1,336,617 ',
#   'Asia',
#   '3,39235',
#   ''],
#  ['',
#   '198',
#   'Wallis and Futuna',
#   '352',
#   '+11',
#   '3 ',
#   '',
#   '18',
#   '',
#   '331',
#   '4',
#   '31,729',
#   '270',
#   '1,331',
#   '119,975',
#   '11,094 ',
#   'Australia/Oceania',
#   '323,6988',
#   ''],
#  ['',
#   '199',
#   'Brunei ',
#   '206',
#   '',
#   '3 ',
#   '',
#   '188',
#   '',
#   '15',
#   '',
#   '468',
#   '7',
#   '112,060',
#   '254,379',
#   '440,524 ',
#   'Asia',
#   '2,138146,8414',
#   ''],
#  ['',
#   '200',
#   'Dominica',
#   '160',
#   '',
#   ' ',
#   '',
#   '151',
#   '',
#   '9',
#   '',
#   '2,219',
#   '',
#   '12,936',
#   '179,378',
#   '72,116 ',
#   'North America',
#   '4516',
#   ''],
#  ['',
#   '201',
#   'Grenada',
#   '154',
#   '',
#   '1 ',
#   '',
#   '151',
#   '',
#   '2',
#   '',
#   '1,364',
#   '9',
#   '23,330',
#   '206,638',
#   '112,903 ',
#   'North America',
#   '733112,9035',
#   ''],
#  ['',
#   '202',
#   'British Virgin Islands',
#   '153',
#   '',
#   '1 ',
#   '',
#   '131',
#   '',
#   '21',
#   '',
#   '5,037',
#   '33',
#   '13,223',
#   '435,296',
#   '30,377 ',
#   'North America',
#   '19930,3772',
#   ''],
#  ['',
#   '203',
#   'New Caledonia',
#   '120',
#   '+4',
#   ' ',
#   '',
#   '58',
#   '',
#   '62',
#   '',
#   '417',
#   '',
#   '27,423',
#   '95,387',
#   '287,493 ',
#   'Australia/Oceania',
#   '2,39610',
#   ''],
#  ['',
#   '204',
#   'Fiji',
#   '67',
#   '',
#   '2 ',
#   '',
#   '64',
#   '',
#   '1',
#   '',
#   '74',
#   '2',
#   '34,782',
#   '38,596',
#   '901,171 ',
#   'Australia/Oceania',
#   '13,450450,58626',
#   ''],
#  ['',
#   '206',
#   'Laos',
#   '49',
#   '',
#   ' ',
#   '',
#   '45',
#   '',
#   '4',
#   '',
#   '7',
#   '',
#   '128,483',
#   '17,476',
#   '7,352,123 ',
#   'Asia',
#   '150,04357',
#   ''],
#  ['',
#   '208',
#   'Saint Kitts and Nevis',
#   '44',
#   '',
#   ' ',
#   '',
#   '42',
#   '',
#   '2',
#   '',
#   '823',
#   '',
#   '10,591',
#   '198,063',
#   '53,473 ',
#   'North America',
#   '1,2155',
#   ''],
#  ['',
#   '210',
#   'Vatican City',
#   '27',
#   '',
#   ' ',
#   '',
#   '15',
#   '',
#   '12',
#   '',
#   '33,666',
#   '',
#   '',
#   '',
#   '802 ',
#   'Europe',
#   '30',
#   ''],
#  ['',
#   '212',
#   'Anguilla',
#   '22',
#   '',
#   ' ',
#   '',
#   '20',
#   '',
#   '2',
#   '',
#   '1,457',
#   '',
#   '11,052',
#   '731,921',
#   '15,100 ',
#   'North America',
#   '6861',
#   ''],
#  ['',
#   '214',
#   'Solomon Islands',
#   '18',
#   '',
#   ' ',
#   '',
#   '16',
#   '',
#   '2',
#   '',
#   '26',
#   '',
#   '4,500',
#   '6,437',
#   '699,041 ',
#   'Australia/Oceania',
#   '38,836155',
#   ''],
#  ['',
#   '215',
#   'Western Sahara',
#   '10',
#   '',
#   '1 ',
#   '',
#   '8',
#   '',
#   '1',
#   '',
#   '16',
#   '2',
#   '',
#   '',
#   '607,939 ',
#   'Africa',
#   '60,794607,939',
#   ''],
#  ['',
#   '218',
#   'Samoa',
#   '3',
#   '',
#   ' ',
#   '',
#   '2',
#   '',
#   '1',
#   '',
#   '15',
#   '',
#   '',
#   '',
#   '199,373 ',
#   'Australia/Oceania',
#   '66,458',
#   ''],
#  ['',
#   '219',
#   'Vanuatu',
#   '3',
#   '',
#   ' ',
#   '',
#   '1',
#   '',
#   '2',
#   '',
#   '10',
#   '',
#   '470',
#   '1,505',
#   '312,328 ',
#   'Australia/Oceania',
#   '104,109665',
#   ''],
#  ['',
#   '221',
#   'China',
#   '90,136',
#   '+11',
#   '4,636 ',
#   '',
#   '85,335',
#   '+4',
#   '165',
#   '',
#   '63',
#   '3',
#   '160,000,000',
#   '111,163',
#   '1,439,323,776 ',
#   'Asia',
#   '15,968310,4679',
#   ''],
#  ['',
#   '',
#   'Total:',
#   '125,555,043',
#   '+139,080',
#   '2,758,995',
#   '+2,810',
#   '101,372,045',
#   '+85,555',
#   '21,424,003',
#   '91,790',
#   '16,107.5',
#   '354.0',
#   '',
#   '',
#   '',
#   'All',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '#',
#   'Country,Other',
#   'TotalCases',
#   'NewCases',
#   'TotalDeaths',
#   'NewDeaths',
#   'TotalRecovered',
#   'NewRecovered',
#   'ActiveCases',
#   'Serious,Critical',
#   'Tot\xa0Cases/1M pop',
#   'Deaths/1M pop',
#   'TotalTests',
#   'Tests/',
#   '1M pop',
#   '',
#   'Population',
#   'Continent',
#   '1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl',
#   ''],
#  ['',
#   '',
#   'World',
#   '125,415,963',
#   '+583,803',
#   '2,756,185',
#   '+10,505',
#   '101,286,490',
#   '+444,921',
#   '21,373,288',
#   '91,598',
#   '16,090',
#   '353.6',
#   '',
#   '',
#   '',
#   'All',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '1',
#   'China',
#   '90,125',
#   '+10',
#   '4,636 ',
#   '',
#   '85,331',
#   '+10',
#   '158',
#   '',
#   '63',
#   '3',
#   '160,000,000',
#   '111,163',
#   '1,439,323,776 ',
#   'Asia',
#   '15,970310,4679',
#   ''],
#  ['',
#   '2',
#   'USA',
#   '30,704,292',
#   '+66,538',
#   '558,422 ',
#   '+1,405',
#   '23,132,879',
#   '+93,294',
#   '7,012,991',
#   '8,623',
#   '92,367',
#   '1,680',
#   '393,863,548',
#   '1,184,853',
#   '332,415,597 ',
#   'North America',
#   '115951',
#   ''],
#  ['',
#   '3',
#   'Brazil',
#   '12,227,179',
#   '+90,564',
#   '301,087 ',
#   '+2,244',
#   '10,689,646',
#   '+87,988',
#   '1,236,446',
#   '8,318',
#   '57,228',
#   '1,409',
#   '28,600,000',
#   '133,858',
#   '213,658,752 ',
#   'South America',
#   '177107',
#   ''],
#  ['',
#   '4',
#   'India',
#   '11,787,013',
#   '+53,419',
#   '160,726 ',
#   '+249',
#   '11,229,591',
#   '+26,575',
#   '396,696',
#   '8,944',
#   '8,481',
#   '116',
#   '236,438,861',
#   '170,117',
#   '1,389,864,267 ',
#   'Asia',
#   '1188,6476',
#   ''],
#  ['',
#   '5',
#   'Russia',
#   '4,483,471',
#   '+8,861',
#   '96,219 ',
#   '+401',
#   '4,098,400',
#   '+10,355',
#   '288,852',
#   '2,300',
#   '30,713',
#   '659',
#   '118,100,000',
#   '809,014',
#   '145,980,114 ',
#   'Europe',
#   '331,5171',
#   ''],
#  ['',
#   '6',
#   'France',
#   '4,378,446',
#   '+33,389',
#   '93,180 ',
#   '+272',
#   '283,507',
#   '',
#   '4,001,759',
#   '4,634',
#   '66,970',
#   '1,425',
#   '60,773,434',
#   '929,559',
#   '65,378,809 ',
#   'Europe',
#   '157021',
#   ''],
#  ['',
#   '7',
#   'UK',
#   '4,312,908',
#   '+5,605',
#   '126,382 ',
#   '+98',
#   '3,729,155',
#   '+16,497',
#   '457,371',
#   '711',
#   '63,290',
#   '1,855',
#   '118,204,895',
#   '1,734,591',
#   '68,145,669 ',
#   'Europe',
#   '165391',
#   ''],
#  ['',
#   '8',
#   'Italy',
#   '3,440,862',
#   '+21,267',
#   '106,339 ',
#   '+460',
#   '2,773,215',
#   '+20,132',
#   '561,308',
#   '3,588',
#   '56,971',
#   '1,761',
#   '47,759,055',
#   '790,753',
#   '60,396,918 ',
#   'Europe',
#   '185681',
#   ''],
#  ['',
#   '9',
#   'Spain',
#   '3,241,345',
#   '+7,026',
#   '74,064 ',
#   '+320',
#   '3,000,670',
#   '+7,822',
#   '166,611',
#   '1,855',
#   '69,307',
#   '1,584',
#   '41,884,958',
#   '895,590',
#   '46,767,990 ',
#   'Europe',
#   '146311',
#   ''],
#  ['',
#   '10',
#   'Turkey',
#   '3,091,282',
#   '+29,762',
#   '30,462 ',
#   '+146',
#   '2,881,643',
#   '+17,761',
#   '179,177',
#   '1,720',
#   '36,369',
#   '358',
#   '36,990,175',
#   '435,187',
#   '84,998,318 ',
#   'Asia',
#   '272,7902',
#   ''],
#  ['',
#   '11',
#   'Germany',
#   '2,709,872',
#   '+20,667',
#   '75,911 ',
#   '+203',
#   '2,445,300',
#   '+11,500',
#   '188,661',
#   '3,209',
#   '32,268',
#   '904',
#   '47,578,793',
#   '566,555',
#   '83,979,174 ',
#   'Europe',
#   '311,1062',
#   ''],
#  ['',
#   '12',
#   'Colombia',
#   '2,353,210',
#   '+5,986',
#   '62,394 ',
#   '+120',
#   '2,244,522',
#   '+4,586',
#   '46,294',
#   '1,982',
#   '45,892',
#   '1,217',
#   '12,386,993',
#   '241,571',
#   '51,276,879 ',
#   'South America',
#   '228224',
#   ''],
#  ['',
#   '13',
#   'Argentina',
#   '2,269,877',
#   '+8,300',
#   '54,946 ',
#   '+123',
#   '2,049,035',
#   '+5,078',
#   '165,896',
#   '3,574',
#   '49,890',
#   '1,208',
#   '8,477,597',
#   '186,332',
#   '45,497,251 ',
#   'South America',
#   '208285',
#   ''],
#  ['',
#   '14',
#   'Mexico',
#   '2,203,041',
#   '+5,881',
#   '199,048 ',
#   '+809',
#   '1,744,262',
#   '+4,008',
#   '259,731',
#   '4,798',
#   '16,957',
#   '1,532',
#   '5,931,263',
#   '45,654',
#   '129,916,892 ',
#   'North America',
#   '5965322',
#   ''],
#  ['',
#   '15',
#   'Poland',
#   '2,120,670',
#   '+29,977',
#   '50,340 ',
#   '+575',
#   '1,707,846',
#   '+13,971',
#   '362,484',
#   '2,537',
#   '56,078',
#   '1,331',
#   '11,400,455',
#   '301,469',
#   '37,816,353 ',
#   'Europe',
#   '187513',
#   ''],
#  ['',
#   '16',
#   'Iran',
#   '1,823,317',
#   '+7,605',
#   '62,045 ',
#   '+94',
#   '1,562,709',
#   '+6,943',
#   '198,563',
#   '3,874',
#   '21,508',
#   '732',
#   '12,349,804',
#   '145,681',
#   '84,773,193 ',
#   'Asia',
#   '461,3667',
#   ''],
#  ['',
#   '17',
#   'Ukraine',
#   '1,579,906',
#   '+14,174',
#   '30,773 ',
#   '+342',
#   '1,276,272',
#   '+7,386',
#   '272,861',
#   '177',
#   '36,285',
#   '707',
#   '7,778,231',
#   '178,639',
#   '43,541,616 ',
#   'Europe',
#   '281,4156',
#   ''],
#  ['',
#   '18',
#   'South Africa',
#   '1,540,009',
#   '+1,048',
#   '52,372 ',
#   '+121',
#   '1,466,595',
#   '+1,391',
#   '21,042',
#   '546',
#   '25,731',
#   '875',
#   '9,690,815',
#   '161,914',
#   '59,851,438 ',
#   'Africa',
#   '391,1436',
#   ''],
#  ['',
#   '19',
#   'Peru',
#   '1,492,519',
#   '+11,260',
#   '50,656 ',
#   '+182',
#   '1,406,304',
#   '+8,963',
#   '35,559',
#   '2,253',
#   '44,814',
#   '1,521',
#   '8,881,594',
#   '266,674',
#   '33,305,026 ',
#   'South America',
#   '226574',
#   ''],
#  ['',
#   '20',
#   'Czechia',
#   '1,486,598',
#   '+10,957',
#   '25,367 ',
#   '+174',
#   '1,294,908',
#   '+483',
#   '166,323',
#   '1,890',
#   '138,630',
#   '2,366',
#   '11,278,655',
#   '1,051,773',
#   '10,723,467 ',
#   'Europe',
#   '74231',
#   ''],
#  ['',
#   '21',
#   'Indonesia',
#   '1,476,452',
#   '+5,227',
#   '39,983 ',
#   '+118',
#   '1,312,543',
#   '+7,622',
#   '123,926',
#   '',
#   '5,357',
#   '145',
#   '12,270,150',
#   '44,518',
#   '275,624,849 ',
#   'Asia',
#   '1876,89422',
#   ''],
#  ['',
#   '22',
#   'Netherlands',
#   '1,220,945',
#   '+7,579',
#   '16,371 ',
#   '+32',
#   'N/A',
#   'N/A',
#   'N/A',
#   '625',
#   '71,140',
#   '954',
#   '9,747,836',
#   '567,973',
#   '17,162,512 ',
#   'Europe',
#   '141,0482',
#   ''],
#  ['',
#   '23',
#   'Chile',
#   '947,783',
#   '+4,825',
#   '22,402 ',
#   '+18',
#   '888,826',
#   '+6,054',
#   '36,555',
#   '2,348',
#   '49,273',
#   '1,165',
#   '10,739,277',
#   '558,305',
#   '19,235,515 ',
#   'South America',
#   '208592',
#   ''],
#  ['',
#   '24',
#   'Canada',
#   '946,370',
#   '+4,050',
#   '22,759 ',
#   '+24',
#   '886,512',
#   '+3,237',
#   '37,099',
#   '586',
#   '24,916',
#   '599',
#   '26,858,481',
#   '707,123',
#   '37,982,749 ',
#   'North America',
#   '401,6691',
#   ''],
#  ['',
#   '25',
#   'Romania',
#   '913,143',
#   '+6,136',
#   '22,579 ',
#   '+137',
#   '819,799',
#   '+5,617',
#   '70,765',
#   '1,351',
#   '47,699',
#   '1,179',
#   '7,080,758',
#   '369,872',
#   '19,143,818 ',
#   'Europe',
# ...
#   '',
#   '87 ',
#   '',
#   '9,995',
#   '',
#   '6,682',
#   '6',
#   '55,097',
#   '286',
#   '153,467',
#   '504,384',
#   '304,266 ',
#   'South America',
#   '183,4972',
#   ''],
#  ['',
#   '130',
#   'Cabo Verde',
#   '16,555',
#   '+38',
#   '163 ',
#   '+3',
#   '15,845',
#   '+41',
#   '547',
#   '23',
#   '29,543',
#   '291',
#   '125,300',
#   '223,601',
#   '560,373 ',
#   'Africa',
#   '343,4384',
#   ''],
#  ['',
#   '131',
#   'Réunion',
#   '15,561',
#   '+930',
#   '102 ',
#   '+15',
#   '14,064',
#   '+955',
#   '1,395',
#   '57',
#   '17,291',
#   '113',
#   '98,785',
#   '109,766',
#   '899,961 ',
#   'Africa',
#   '588,8239',
#   ''],
#  ['',
#   '133',
#   'Haiti',
#   '12,732',
#   '+10',
#   '251 ',
#   '',
#   '10,754',
#   '+87',
#   '1,727',
#   '',
#   '1,107',
#   '22',
#   '54,379',
#   '4,727',
#   '11,503,439 ',
#   'North America',
#   '90445,830212',
#   ''],
#  ['',
#   '134',
#   'Burkina Faso',
#   '12,572',
#   '+13',
#   '145 ',
#   '',
#   '12,240',
#   '+63',
#   '187',
#   '',
#   '590',
#   '7',
#   '',
#   '',
#   '21,316,388 ',
#   'Africa',
#   '1,696147,010',
#   ''],
#  ['',
#   '135',
#   'Belize',
#   '12,410',
#   '+3',
#   '316 ',
#   '',
#   '12,047',
#   '+16',
#   '47',
#   '',
#   '30,805',
#   '784',
#   '95,000',
#   '235,817',
#   '402,854 ',
#   'North America',
#   '321,2754',
#   ''],
#  ['',
#   '136',
#   'Andorra',
#   '11,591',
#   '+46',
#   '113 ',
#   '',
#   '11,050',
#   '+36',
#   '428',
#   '12',
#   '149,842',
#   '1,461',
#   '193,595',
#   '2,502,682',
#   '77,355 ',
#   'Europe',
#   '76850',
#   ''],
#  ['',
#   '137',
#   'Hong Kong',
#   '11,410',
#   '+12',
#   '204 ',
#   '+1',
#   '10,936',
#   '+35',
#   '270',
#   '10',
#   '1,513',
#   '27',
#   '9,296,529',
#   '1,232,763',
#   '7,541,215 ',
#   'Asia',
#   '66136,9671',
#   ''],
#  ['',
#   '138',
#   'Guadeloupe',
#   '10,976',
#   '',
#   '165 ',
#   '',
#   '2,242',
#   '',
#   '8,569',
#   '8',
#   '27,428',
#   '412',
#   '145,313',
#   '363,125',
#   '400,174 ',
#   'North America',
#   '362,4253',
#   ''],
#  ['',
#   '139',
#   'Lesotho',
#   '10,685',
#   '+147',
#   '314 ',
#   '+5',
#   '4,390',
#   '+468',
#   '5,981',
#   '',
#   '4,959',
#   '146',
#   '65,626',
#   '30,459',
#   '2,154,601 ',
#   'Africa',
#   '2026,86233',
#   ''],
#  ['',
#   '140',
#   'Somalia',
#   '10,369',
#   '+155',
#   '453 ',
#   '+12',
#   '4,564',
#   '+32',
#   '5,352',
#   '',
#   '640',
#   '28',
#   '',
#   '',
#   '16,212,726 ',
#   'Africa',
#   '1,56435,790',
#   ''],
#  ['',
#   '141',
#   'South Sudan',
#   '9,919',
#   '+29',
#   '106 ',
#   '',
#   '9,002',
#   '+223',
#   '811',
#   '1',
#   '879',
#   '9',
#   '125,721',
#   '11,137',
#   '11,289,017 ',
#   'Africa',
#   '1,138106,50090',
#   ''],
#  ['',
#   '142',
#   'Guyana',
#   '9,732',
#   '+64',
#   '218  ',
#   '+2',
#   '8,602',
#   '+80',
#   '912',
#   '11',
#   '12,330',
#   '276',
#   '83,368',
#   '105,621',
#   '789,316 ',
#   'South America',
#   '813,6219',
#   ''],
#  ['',
#   '143',
#   'Congo',
#   '9,564',
#   '',
#   '134 ',
#   '',
#   '7,514',
#   '',
#   '1,916',
#   '',
#   '1,703',
#   '24',
#   '92,500',
#   '16,470',
#   '5,616,113 ',
#   'Africa',
#   '58741,91161',
#   ''],
#  ['',
#   '144',
#   'Mali',
#   '9,474',
#   '+94',
#   '372 ',
#   '+1',
#   '6,661',
#   '+17',
#   '2,441',
#   '',
#   '458',
#   '18',
#   '159,785',
#   '7,730',
#   '20,670,941 ',
#   'Africa',
#   '2,18255,567129',
#   ''],
#  ['',
#   '145',
#   'Togo',
#   '9,147',
#   '+187',
#   '105 ',
#   '+1',
#   '7,341',
#   '+99',
#   '1,701',
#   '',
#   '1,086',
#   '12',
#   '263,543',
#   '31,304',
#   '8,418,839 ',
#   'Africa',
#   '92080,17932',
#   ''],
#  ['',
#   '146',
#   'Suriname',
#   '9,074',
#   '+7',
#   '177 ',
#   '',
#   '8,564',
#   '+4',
#   '333',
#   '2',
#   '15,368',
#   '300',
#   '43,939',
#   '74,416',
#   '590,453 ',
#   'South America',
#   '653,33613',
#   ''],
#  ['',
#   '147',
#   'Bahamas',
#   '8,935',
#   '+12',
#   '188 ',
#   '',
#   '7,757',
#   '+23',
#   '990',
#   '3',
#   '22,565',
#   '475',
#   '73,721',
#   '186,176',
#   '395,975 ',
#   'North America',
#   '442,1065',
#   ''],
#  ['',
#   '148',
#   'Aruba',
#   '8,902',
#   '+102',
#   '82 ',
#   '',
#   '8,310',
#   '+18',
#   '510',
#   '8',
#   '83,122',
#   '766',
#   '119,810',
#   '1,118,716',
#   '107,096 ',
#   'North America',
#   '121,3061',
#   ''],
#  ['',
#   '149',
#   'Trinidad and Tobago',
#   '7,865',
#   '+4',
#   '141 ',
#   '+1',
#   '7,573',
#   '+2',
#   '151',
#   '2',
#   '5,607',
#   '101',
#   '108,872',
#   '77,611',
#   '1,402,791 ',
#   'North America',
#   '1789,94913',
#   ''],
#  ['',
#   '150',
#   'Martinique',
#   '7,710',
#   '+401',
#   '49 ',
#   '+2',
#   '98',
#   '',
#   '7,563',
#   '5',
#   '20,557',
#   '131',
#   '118,816',
#   '316,798',
#   '375,053 ',
#   'North America',
#   '497,6543',
#   ''],
#  ['',
#   '151',
#   'Benin',
#   '6,818',
#   '',
#   '90 ',
#   '',
#   '5,552',
#   '',
#   '1,176',
#   '35',
#   '552',
#   '7',
#   '521,218',
#   '42,196',
#   '12,352,199 ',
#   'Africa',
#   '1,812137,24724',
#   ''],
#  ['',
#   '152',
#   'Equatorial Guinea',
#   '6,780',
#   '',
#   '101 ',
#   '',
#   '6,244',
#   '',
#   '435',
#   '10',
#   '4,721',
#   '70',
#   '106,588',
#   '74,220',
#   '1,436,117 ',
#   'Africa',
#   '21214,21913',
#   ''],
#  ['',
#   '153',
#   'Djibouti',
#   '6,771',
#   '+113',
#   '64 ',
#   '',
#   '6,146',
#   '+33',
#   '561',
#   '',
#   '6,782',
#   '64',
#   '124,026',
#   '124,222',
#   '998,419 ',
#   'Africa',
#   '14715,6008',
#   ''],
#  ['',
#   '154',
#   'Nicaragua',
#   '6,629',
#   '+47',
#   '177 ',
#   '+1',
#   '4,225',
#   '',
#   '2,227',
#   '',
#   '992',
#   '26',
#   '',
#   '',
#   '6,681,779 ',
#   'North America',
#   '1,00837,750',
#   ''],
#  ['',
#   '155',
#   'Curaçao',
#   '6,174',
#   '+133',
#   '24 ',
#   '',
#   '4,891',
#   '+34',
#   '1,259',
#   '9',
#   '37,513',
#   '146',
#   '60,949',
#   '370,326',
#   '164,582 ',
#   'North America',
#   '276,8583',
#   ''],
#  ['',
#   '156',
#   'Iceland',
#   '6,122',
#   '+3',
#   '29 ',
#   '',
#   '6,036',
#   '+1',
#   '57',
#   '1',
#   '17,856',
#   '85',
#   '525,321',
#   '1,532,196',
#   '342,855 ',
#   'Europe',
#   '5611,8231',
#   ''],
#  ['',
#   '157',
#   'Mongolia',
#   '5,392',
#   '+206',
#   '5 ',
#   '',
#   '3,758',
#   '+152',
#   '1,629',
#   '18',
#   '1,626',
#   '2',
#   '2,133,339',
#   '643,241',
#   '3,316,547 ',
#   'Asia',
#   '615663,3092',
#   ''],
#  ['',
#   '158',
#   'Gambia',
#   '5,255',
#   '',
#   '161 ',
#   '',
#   '4,875',
#   '',
#   '219',
#   '3',
#   '2,131',
#   '65',
#   '52,941',
#   '21,472',
#   '2,465,585 ',
#   'Africa',
#   '46915,31447',
#   ''],
#  ['',
#   '159',
#   'CAR',
#   '5,087',
#   '',
#   '64 ',
#   '',
#   '4,938',
#   '',
#   '85',
#   '2',
#   '1,040',
#   '13',
#   '38,422',
#   '7,856',
#   '4,890,583 ',
#   'Africa',
#   '96176,415127',
#   ''],
#  ['',
#   '160',
#   'Niger',
#   '4,939',
#   '+11',
#   '185 ',
#   '',
#   '4,553',
#   '+12',
#   '201',
#   '1',
#   '199',
#   '7',
#   '86,912',
#   '3,500',
#   '24,835,440 ',
#   'Africa',
#   '5,028134,246286',
#   ''],
#  ['',
#   '161',
#   'Chad',
#   '4,440',
#   '+13',
#   '158 ',
#   '+1',
#   '4,059',
#   '+14',
#   '223',
#   '',
#   '265',
#   '9',
#   '',
#   '',
#   '16,765,361 ',
#   'Africa',
#   '3,776106,110',
#   ''],
#  ['',
#   '162',
#   'San Marino',
#   '4,436',
#   '+46',
#   '80 ',
#   '+1',
#   '3,874',
#   '+55',
#   '482',
#   '11',
#   '130,536',
#   '2,354',
#   '50,626',
#   '1,489,745',
#   '33,983 ',
#   'Europe',
#   '84251',
#   ''],
#  ['',
#   '163',
#   'Gibraltar',
#   '4,271',
#   '+1',
#   '94 ',
#   '',
#   '4,156',
#   '+8',
#   '21',
#   '1',
#   '126,796',
#   '2,791',
#   '207,124',
#   '6,149,032',
#   '33,684 ',
#   'Europe',
#   '83580',
#   ''],
#  ['',
#   '164',
#   'Saint Lucia',
#   '4,149',
#   '+17',
#   '57 ',
#   '+2',
#   '3,963',
#   '+13',
#   '129',
#   '2',
#   '22,520',
#   '309',
#   '34,927',
#   '189,575',
#   '184,238 ',
#   'North America',
#   '443,2325',
#   ''],
#  ['',
#   '166',
#   'Sierra Leone',
#   '3,949',
#   '+1',
#   '79 ',
#   '',
#   '2,792',
#   '+2',
#   '1,078',
#   '',
#   '488',
#   '10',
#   '116,448',
#   '14,386',
#   '8,094,302 ',
#   'Africa',
#   '2,050102,46070',
#   ''],
#  ['',
#   '167',
#   'Seychelles',
#   '3,828',
#   '+30',
#   '18 ',
#   '+2',
#   '3,205',
#   '+48',
#   '605',
#   '',
#   '38,749',
#   '182',
#   '5,200',
#   '52,637',
#   '98,790 ',
#   'Africa',
#   '265,48819',
#   ''],
#  ['',
#   '168',
#   'Papua New Guinea',
#   '3,758',
#   '+184',
#   '37 ',
#   '+1',
#   '846',
#   '',
#   '2,875',
#   '',
#   '414',
#   '4',
#   '55,411',
#   '6,109',
#   '9,069,676 ',
#   'Australia/Oceania',
#   '2,413245,126164',
#   ''],
#  ['',
#   '169',
#   'Comoros',
#   '3,681',
#   '+15',
#   '146 ',
#   '',
#   '3,483',
#   '+10',
#   '52',
#   '',
#   '4,169',
#   '165',
#   '',
#   '',
#   '882,992 ',
#   'Africa',
#   '2406,048',
#   ''],
#  ['',
#   '170',
#   'Yemen',
#   '3,612',
#   '+96',
#   '785 ',
#   '+14',
#   '1,566',
#   '+20',
#   '1,261',
#   '23',
#   '119',
#   '26',
#   '17,544',
#   '579',
#   '30,300,654 ',
#   'Asia',
#   '8,38938,6001,727',
#   ''],
#  ['',
#   '171',
#   'Guinea-Bissau',
#   '3,586',
#   '+18',
#   '56 ',
#   '+1',
#   '2,891',
#   '+21',
#   '639',
#   '16',
#   '1,792',
#   '28',
#   '57,210',
#   '28,582',
#   '2,001,587 ',
#   'Africa',
#   '55835,74335',
#   ''],
#  ['',
#   '172',
#   'Barbados',
#   '3,574',
#   '+15',
#   '40 ',
#   '',
#   '3,390',
#   '+32',
#   '144',
#   '',
#   '12,426',
#   '139',
#   '137,126',
#   '476,741',
#   '287,632 ',
#   'North America',
#   '807,1912',
#   ''],
#  ['',
#   '173',
#   'Eritrea',
#   '3,163',
#   '+45',
#   '8 ',
#   '+1',
#   '2,923',
#   '+58',
#   '232',
#   '',
#   '883',
#   '2',
#   '23,693',
#   '6,614',
#   '3,582,027 ',
#   'Africa',
#   '1,132447,753151',
#   ''],
#  ['',
#   '174',
#   'Liechtenstein',
#   '2,634',
#   '+2',
#   '56 ',
#   '',
#   '2,542',
#   '+6',
#   '36',
#   '',
#   '68,938',
#   '1,466',
#   '29,848',
#   '781,198',
#   '38,208 ',
#   'Europe',
#   '156821',
#   ''],
#  ['',
#   '175',
#   'Burundi',
#   '2,628',
#   '+10',
#   '6 ',
#   '',
#   '773',
#   '',
#   '1,849',
#   '',
#   '216',
#   '0.5',
#   '90,019',
#   '7,412',
#   '12,145,730 ',
#   'Africa',
#   '4,6222,024,288135',
#   ''],
#  ['',
#   '176',
#   'Vietnam',
#   '2,575',
#   '',
#   '35 ',
#   '',
#   '2,246',
#   '+13',
#   '294',
#   '',
#   '26',
#   '0.4',
#   '2,598,753',
#   '26,525',
#   '97,975,281 ',
#   'Asia',
#   '38,0492,799,29438',
#   ''],
#  ['',
#   '177',
#   'New Zealand',
#   '2,462',
#   '',
#   '26 ',
#   '',
#   '2,373',
#   '',
#   '63',
#   '',
#   '492',
#   '5',
#   '1,852,557',
#   '370,356',
#   '5,002,100 ',
#   'Australia/Oceania',
#   '2,032192,3883',
#   ''],
#  ['',
#   '178',
#   'Turks and Caicos',
#   '2,307',
#   '+13',
#   '17 ',
#   '',
#   '2,174',
#   '+47',
#   '116',
#   '2',
#   '59,007',
#   '435',
#   '20,896',
#   '534,466',
#   '39,097 ',
#   'North America',
#   '172,3002',
#   ''],
#  ['',
#   '179',
#   'Monaco',
#   '2,199',
#   '+17',
#   '27 ',
#   '',
#   '2,030',
#   '+10',
#   '142',
#   '4',
#   '55,750',
#   '685',
#   '51,953',
#   '1,317,133',
#   '39,444 ',
#   'Europe',
#   '181,4611',
#   ''],
#  ['',
#   '180',
#   'Sao Tome and Principe',
#   '2,159',
#   '+2',
#   '34 ',
#   '',
#   '1,999',
#   '+11',
#   '126',
#   '',
#   '9,721',
#   '153',
#   '11,592',
#   '52,192',
#   '222,105 ',
#   'Africa',
#   '1036,53319',
#   ''],
#  ['',
#   '181',
#   'Sint Maarten',
#   '2,108',
#   '+4',
#   '27 ',
#   '',
#   '2,060',
#   '+2',
#   '21',
#   '1',
#   '48,764',
#   '625',
#   '22,989',
#   '531,796',
#   '43,229 ',
#   'North America',
#   '211,6012',
#   ''],
#  ['',
#   '182',
#   'Liberia',
#   '2,042',
#   '',
#   '85 ',
#   '',
#   '1,899',
#   '',
#   '58',
#   '2',
#   '397',
#   '17',
#   '79,684',
#   '15,492',
#   '5,143,521 ',
#   'Africa',
#   '2,51960,51265',
#   ''],
#  ['',
#   '183',
#   'Cambodia',
#   '1,788',
#   '+35',
#   '4 ',
#   '+1',
#   '999',
#   '+32',
#   '785',
#   '',
#   '106',
#   '0.2',
#   '640,904',
#   '37,953',
#   '16,886,814 ',
#   'Asia',
#   '9,4454,221,70426',
#   ''],
#  ['',
#   '184',
#   'St. Vincent Grenadines',
#   '1,700',
#   '',
#   '10 ',
#   '',
#   '1,523',
#   '',
#   '167',
#   '2',
#   '15,288',
#   '90',
#   '39,546',
#   '355,639',
#   '111,197 ',
#   'North America',
#   '6511,1203',
#   ''],
#  ['',
#   '185',
#   'Saint Martin',
#   '1,619',
#   '',
#   '12 ',
#   '',
#   '1,399',
#   '',
#   '208',
#   '7',
#   '41,360',
#   '307',
#   '23,812',
#   '608,318',
#   '39,144 ',
#   'North America',
#   '243,2622',
#   ''],
#  ['',
#   '186',
#   'Isle of Man',
#   '1,516',
#   '+13',
#   '26 ',
#   '',
#   '702',
#   '+105',
#   '788',
#   '12',
#   '17,760',
#   '305',
#   '42,077',
#   '492,930',
#   '85,361 ',
#   'Europe',
#   '563,2832',
#   ''],
#  ['',
#   '187',
#   'Caribbean Netherlands',
#   '1,119',
#   '+1',
#   '10 ',
#   '+1',
#   '648',
#   '+29',
#   '461',
#   '',
#   '42,386',
#   '379',
#   '8,599',
#   '325,720',
#   '26,400 ',
#   'North America',
#   '242,6403',
#   ''],
#  ['',
#   '188',
#   'Antigua and Barbuda',
#   '1,080',
#   '+8',
#   '28 ',
#   '',
#   '715',
#   '+14',
#   '337',
#   '45',
#   '10,962',
#   '284',
#   '16,190',
#   '164,334',
#   '98,519 ',
#   'North America',
#   '913,5196',
#   ''],
#  ['',
#   '189',
#   'Taiwan',
#   '1,007',
#   '+1',
#   '10 ',
#   '',
#   '969',
#   '+6',
#   '28',
#   '',
#   '42',
#   '0.4',
#   '459,223',
#   '19,256',
#   '23,848,207 ',
#   'Asia',
#   '23,6822,384,82152',
#   ''],
#  ['',
#   '190',
#   'Bhutan',
#   '869',
#   '',
#   '1 ',
#   '',
#   '867',
#   '',
#   '1',
#   '',
#   '1,117',
#   '1',
#   '578,215',
#   '743,418',
#   '777,779 ',
#   'Asia',
#   '895777,7791',
#   ''],
#  ['',
#   '191',
#   'Mauritius',
#   '850',
#   '+3',
#   '10 ',
#   '',
#   '592',
#   '',
#   '248',
#   '',
#   '668',
#   '8',
#   '289,552',
#   '227,402',
#   '1,273,307 ',
#   'Africa',
#   '1,498127,3314',
#   ''],
#  ['',
#   '192',
#   'Bermuda',
#   '840',
#   '+10',
#   '12 ',
#   '',
#   '715',
#   '+3',
#   '113',
#   '',
#   '13,524',
#   '193',
#   '189,077',
#   '3,044,228',
#   '62,110 ',
#   'North America',
#   '745,1760',
#   ''],
#  ['',
#   '193',
#   'St. Barth',
#   '775',
#   '',
#   '1 ',
#   '',
#   '462',
#   '',
#   '312',
#   '',
#   '78,291',
#   '101',
#   '21,651',
#   '2,187,191',
#   '9,899 ',
#   'North America',
#   '139,8990',
#   ''],
#  ['',
#   '196',
#   'Tanzania',
#   '509',
#   '',
#   '21 ',
#   '',
#   '183',
#   '',
#   '305',
#   '7',
#   '8',
#   '0.3',
#   '',
#   '',
#   '60,959,861 ',
#   'Africa',
#   '119,7642,902,851',
#   ''],
#  ['',
#   '197',
#   'Cayman Islands',
#   '482',
#   '',
#   '2 ',
#   '',
#   '448',
#   '',
#   '32',
#   '',
#   '7,272',
#   '30',
#   '79,727',
#   '1,202,845',
#   '66,282 ',
#   'North America',
#   '13833,1411',
#   ''],
#  ['',
#   '198',
#   'Timor-Leste',
#   '351',
#   '+16',
#   ' ',
#   '',
#   '124',
#   '',
#   '227',
#   '',
#   '263',
#   '',
#   '36,580',
#   '27,368',
#   '1,336,617 ',
#   'Asia',
#   '3,80837',
#   ''],
#  ['',
#   '199',
#   'Wallis and Futuna',
#   '329',
#   '+11',
#   '2 ',
#   '+1',
#   '18',
#   '+5',
#   '309',
#   '4',
#   '29,656',
#   '180',
#   '1,331',
#   '119,975',
#   '11,094 ',
#   'Australia/Oceania',
#   '345,5478',
#   ''],
#  ['',
#   '200',
#   'Brunei ',
#   '206',
#   '',
#   '3 ',
#   '',
#   '188',
#   '',
#   '15',
#   '',
#   '468',
#   '7',
#   '112,060',
#   '254,379',
#   '440,524 ',
#   'Asia',
#   '2,138146,8414',
#   ''],
#  ['',
#   '201',
#   'Dominica',
#   '156',
#   '',
#   ' ',
#   '',
#   '141',
#   '',
#   '15',
#   '',
#   '2,163',
#   '',
#   '12,325',
#   '170,905',
#   '72,116 ',
#   'North America',
#   '4626',
#   ''],
#  ['',
#   '202',
#   'Grenada',
#   '154',
#   '',
#   '1 ',
#   '',
#   '151',
#   '',
#   '2',
#   '',
#   '1,364',
#   '9',
#   '23,330',
#   '206,638',
#   '112,903 ',
#   'North America',
#   '733112,9035',
#   ''],
#  ['',
#   '203',
#   'British Virgin Islands',
#   '153',
#   '',
#   '1 ',
#   '',
#   '131',
#   '',
#   '21',
#   '',
#   '5,037',
#   '33',
#   '13,223',
#   '435,296',
#   '30,377 ',
#   'North America',
#   '19930,3772',
#   ''],
#  ['',
#   '204',
#   'New Caledonia',
#   '116',
#   '',
#   ' ',
#   '',
#   '58',
#   '',
#   '58',
#   '2',
#   '403',
#   '',
#   '26,871',
#   '93,467',
#   '287,493 ',
#   'Australia/Oceania',
#   '2,47811',
#   ''],
#  ['',
#   '205',
#   'Fiji',
#   '67',
#   '',
#   '2 ',
#   '',
#   '64',
#   '',
#   '1',
#   '',
#   '74',
#   '2',
#   '34,782',
#   '38,596',
#   '901,171 ',
#   'Australia/Oceania',
#   '13,450450,58626',
#   ''],
#  ['',
#   '207',
#   'Laos',
#   '49',
#   '',
#   ' ',
#   '',
#   '45',
#   '',
#   '4',
#   '',
#   '7',
#   '',
#   '127,582',
#   '17,353',
#   '7,352,123 ',
#   'Asia',
#   '150,04358',
#   ''],
#  ['',
#   '208',
#   'Macao',
#   '48',
#   '',
#   ' ',
#   '',
#   '47',
#   '',
#   '1',
#   '',
#   '73',
#   '',
#   '4,369',
#   '6,663',
#   '655,757 ',
#   'Asia',
#   '13,662150',
#   ''],
#  ['',
#   '209',
#   'Saint Kitts and Nevis',
#   '44',
#   '',
#   ' ',
#   '',
#   '42',
#   '',
#   '2',
#   '',
#   '823',
#   '',
#   '10,591',
#   '198,063',
#   '53,473 ',
#   'North America',
#   '1,2155',
#   ''],
#  ['',
#   '211',
#   'Vatican City',
#   '27',
#   '',
#   ' ',
#   '',
#   '15',
#   '',
#   '12',
#   '',
#   '33,666',
#   '',
#   '',
#   '',
#   '802 ',
#   'Europe',
#   '30',
#   ''],
#  ['',
#   '213',
#   'Anguilla',
#   '22',
#   '',
#   ' ',
#   '',
#   '20',
#   '',
#   '2',
#   '',
#   '1,457',
#   '',
#   '11,052',
#   '731,921',
#   '15,100 ',
#   'North America',
#   '6861',
#   ''],
#  ['',
#   '215',
#   'Solomon Islands',
#   '18',
#   '',
#   ' ',
#   '',
#   '16',
#   '',
#   '2',
#   '',
#   '26',
#   '',
#   '4,500',
#   '6,437',
#   '699,041 ',
#   'Australia/Oceania',
#   '38,836155',
#   ''],
#  ['',
#   '216',
#   'Western Sahara',
#   '10',
#   '',
#   '1 ',
#   '',
#   '8',
#   '',
#   '1',
#   '',
#   '16',
#   '2',
#   '',
#   '',
#   '607,939 ',
#   'Africa',
#   '60,794607,939',
#   ''],
#  ['',
#   '219',
#   'Samoa',
#   '3',
#   '',
#   ' ',
#   '',
#   '2',
#   '',
#   '1',
#   '',
#   '15',
#   '',
#   '',
#   '',
#   '199,373 ',
#   'Australia/Oceania',
#   '66,458',
#   ''],
#  ['',
#   '220',
#   'Vanuatu',
#   '3',
#   '',
#   ' ',
#   '',
#   '1',
#   '',
#   '2',
#   '',
#   '10',
#   '',
#   '470',
#   '1,505',
#   '312,328 ',
#   'Australia/Oceania',
#   '104,109665',
#   ''],
#  ['',
#   '',
#   'Total:',
#   '124,832,160',
#   '+506,028',
#   '2,745,680',
#   '+10,427',
#   '100,841,569',
#   '+439,983',
#   '21,244,911',
#   '91,270',
#   '16,014.8',
#   '352.2',
#   '',
#   '',
#   '',
#   'All',
#   '',
#   '',
#   '',
#   '',
#   '']]
